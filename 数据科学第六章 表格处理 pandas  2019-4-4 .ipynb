# %% [markdown]
# ### 1.处理截面数据  series 没有前后顺序和相关关系
# ### 2.时间序列数据 time series 观测值之间有先后数据
# ### 3.数据框架
# ### 4.面板数据 panel data analysis 面板数据分析 pandas   每个个体有多个不同指标，可以搞出多层

# %%
df=pd.DataFrame({"Numble of Petals":[8,34,5],
                 "Names":["lotus", "sunflower", "rose"]})
df
# Out:
#    Numble of Petals      Names
# 0                 8      lotus
# 1                34  sunflower
# 2                 5       rose

# %% [markdown]
# # DataFrame

# %%
df["color"]=["Pink","Yellow","Red"]
df
# Out:
#    Numble of Petals   color      Names
# 0                 8    Pink      lotus
# 1                34  Yellow  sunflower
# 2                 5     Red       rose

# %%
print(flower)
# Out:
# None

# %%
import pandas as pd
df=pd.DataFrame([8,34,5],
               columns=["Numble of petals"])
df
# Out:
#    Numble of petals
# 0                 8
# 1                34
# 2                 5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#mat matri矩阵x plot绘制 lib实验室.py plot

# %%
s=pd.Series([1,2,np.nan,4])
#np.nan not a number 不是一个数 缺失值
#S要大写

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# dtype: float64

# %%
#输出序列的索引
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
#输出序列的值
s.values
# Out:
# array([ 1.,  2., nan,  4.])

# %%
#可以指定索引
s=pd.Series([1,2,np.nan,4],index=["A","B","C","D"])
#有括弧括起来，不需要反斜杠来换行
s
# Out:
# A    1.0
# B    2.0
# C    NaN
# D    4.0
# dtype: float64

# %%
#可以指定索引
s=pd.Series([1,2,np.nan,4],index=["第一行","第二行","第三行","第四行"])
s
# Out:
# 第一行    1.0
# 第二行    2.0
# 第三行    NaN
# 第四行    4.0
# dtype: float64

# %%
s=pd.Series([1,2,np.nan,4],index=[2,3,4,6])
s
#索引默认从0开始，可以用中文，英文，字符，和数字
# Out:
# 2    1.0
# 3    2.0
# 4    NaN
# 6    4.0
# dtype: float64

# %%
df=pd.DataFrame(np.arange(6).reshape(2,3))
#把一个列数组变成两行三列
df
# Out:
#    0  1  2
# 0  0  1  2
# 1  3  4  5

# %%
np.arange(6)
#产生的是一个数组
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
df=pd.DataFrame(np.arange(6).reshape(2,3),
               index=["第一行","第二行"],
               columns=["A","B","C"])
df
# Out:
#      A  B  C
# 第一行  0  1  2
# 第二行  3  4  5

# %%
#以指定行列来数据dic来创建DataFrame
#Dic Key Value
import pandas as pd
f=pd.DataFrame({"值班":["A","B","C","D","E"],"星期":["一","二","三","四","五"]})
f
# Out:
#   值班 星期
# 0  A  一
# 1  B  二
# 2  C  三
# 3  D  四
# 4  E  五

# %%
df2=pd.DataFrame(df,columns=["星期","值班"])
df2
# Out:
#      星期  值班
# 第一行 NaN NaN
# 第二行 NaN NaN

# %%
data={"星期":{"first":"one","second":"two"},"值班":{"first":"A","second":"B"}}
df=pd.DataFrame(data)
df
# Out:
#          星期 值班
# first   one  A
# second  two  B

# %%
值班=pd.Series(["A","B","C","D","E"],index=[1,2,3,4,5])
星期=pd.Series(["一","二","三","四","五"],index=[1,2,3,4,5])
df=pd.DataFrame([值班,星期])
df
# Out:
#    1  2  3  4  5
# 0  A  B  C  D  E
# 1  一  二  三  四  五

# %%
值班=pd.Series(["A","B","C","D","E"],index=[1,2,3,4,5])
星期=pd.Series(["二","三","四","五"],index=[2,3,4,5])
df=pd.DataFrame([值班,星期])
df
# Out:
#      1  2  3  4  5
# 0    A  B  C  D  E
# 1  NaN  二  三  四  五

# %%
#对表格进行转置操作
df2=df.T
df2
# Out:
#    0    1
# 1  A  NaN
# 2  B    二
# 3  C    三
# 4  D    四
# 5  E    五

# %% [markdown]
# # 第一个例子

# %%
import pandas as pd
import numpy as np
NumRows=4;
df=pd.DataFrame({"A":pd.date_range("20181101",periods=NumRows),
                 "B":pd.Series(range(NumRows),dtype="float"),
                 "C":np.array(3,dtype="int32"),
                 "D":pd.Categorical(["测试","训练","测试","训练"]),
                 "E":"foo"},
                 index=list(range(NumRows)))
df
# Out:
#            A    B  C   D    E
# 0 2018-11-01  0.0  3  测试  foo
# 1 2018-11-02  1.0  3  训练  foo
# 2 2018-11-03  2.0  3  测试  foo
# 3 2018-11-04  3.0  3  训练  foo

# %%
#获取每一列的数据类型
df.dtypes
# Out:
# A    datetime64[ns]
# B           float64
# C             int32
# D          category
# E            object
# dtype: object

# %%
dff=df>0
#得到一个值为0，其余都为nan，根据布尔条件进行，
dff[dff]
# Out:
#       A    B     C     D     E
# 0  True  NaN  True  True  True
# 1  True  1.0  True  True  True
# 2  True  1.0  True  True  True
# 3  True  1.0  True  True  True

# %%
NumRows=4;
df=pd.DataFrame({"A":pd.date_range("20181101",periods=NumRows),
                 "B":pd.Series(range(NumRows),dtype="float"),
                 "C":np.array(3,dtype="int32"),
                 "D":pd.Categorical(["测试","训练","测试","训练"]),
                 "E":"foo"},
                 index=list(range(NumRows)))
df
# Out:
#            A    B  C   D    E
# 0 2018-11-01  0.0  3  测试  foo
# 1 2018-11-02  1.0  3  训练  foo
# 2 2018-11-03  2.0  3  测试  foo
# 3 2018-11-04  3.0  3  训练  foo

# %%
#访问前几行的数据
df.head(3)
# Out:
#            A    B  C   D    E
# 0 2018-11-01  0.0  3  测试  foo
# 1 2018-11-02  1.0  3  训练  foo
# 2 2018-11-03  2.0  3  测试  foo

# %%
#访问后几行的数据
df.tail(3)
# Out:
#            A    B  C   D    E
# 1 2018-11-02  1.0  3  训练  foo
# 2 2018-11-03  2.0  3  测试  foo
# 3 2018-11-04  3.0  3  训练  foo

# %%
df.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.values
# Out:
# array([[Timestamp('2018-11-01 00:00:00'), 0.0, 3, '测试', 'foo'],
#        [Timestamp('2018-11-02 00:00:00'), 1.0, 3, '训练', 'foo'],
#        [Timestamp('2018-11-03 00:00:00'), 2.0, 3, '测试', 'foo'],
#        [Timestamp('2018-11-04 00:00:00'), 3.0, 3, '训练', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               B    C
# count  4.000000  4.0
# mean   1.500000  3.0
# std    1.290994  0.0
# min    0.000000  3.0
# 25%    0.750000  3.0
# 50%    1.500000  3.0
# 75%    2.250000  3.0
# max    3.000000  3.0

# %%
df.T
# Out:
#                      0                    1                    2  \
# A  2018-11-01 00:00:00  2018-11-02 00:00:00  2018-11-03 00:00:00
# B                    0                    1                    2
# C                    3                    3                    3
# D                   测试                   训练                   测试
# E                  foo                  foo                  foo
#
#                      3
# A  2018-11-04 00:00:00
# B                    3
# C                    3
# D                   训练
# E                  foo

# %%
#对表格按照某个列标签进行排序操作,axis为列，ascending 是否按照升序，False 不按照升序
df.sort_index(axis=1,ascending=False)
# Out:
#      E   D  C    B          A
# 0  foo  测试  3  0.0 2018-11-01
# 1  foo  训练  3  1.0 2018-11-02
# 2  foo  测试  3  2.0 2018-11-03
# 3  foo  训练  3  3.0 2018-11-04

# %%
#根据B这一列的值，按照从小到大升序排列
df.sort_values(by="B")
# Out:
#            A    B  C   D    E
# 0 2018-11-01  0.0  3  测试  foo
# 1 2018-11-02  1.0  3  训练  foo
# 2 2018-11-03  2.0  3  测试  foo
# 3 2018-11-04  3.0  3  训练  foo

# %%
#根据B这一列的值，按照从小到大升序排列
df.sort_values(by="D",ascending=False)
# Out:
#            A    B  C   D    E
# 3 2018-11-04  3.0  3  训练  foo
# 1 2018-11-02  1.0  3  训练  foo
# 2 2018-11-03  2.0  3  测试  foo
# 0 2018-11-01  0.0  3  测试  foo

# %%
#提取表格中的某一列
df["A"]
# Out:
# 0   2018-11-01
# 1   2018-11-02
# 2   2018-11-03
# 3   2018-11-04
# Name: A, dtype: datetime64[ns]

# %%
#e二者等价
df.A
# Out:
# 0   2018-11-01
# 1   2018-11-02
# 2   2018-11-03
# 3   2018-11-04
# Name: A, dtype: datetime64[ns]

# %%
#访问特定的行 前三行
df[0:3]
# Out:
#            A    B  C   D    E
# 0 2018-11-01  0.0  3  测试  foo
# 1 2018-11-02  1.0  3  训练  foo
# 2 2018-11-03  2.0  3  测试  foo

# %%
df.loc[0:2,:]
# Out:
#            A    B  C   D    E
# 0 2018-11-01  0.0  3  测试  foo
# 1 2018-11-02  1.0  3  训练  foo
# 2 2018-11-03  2.0  3  测试  foo

# %% [markdown]
# ### loc 通过行和列的索引（名称）来访问数据
# ### iloc 通过行和列的下标来访问数据,按照行和列的位置，

# %%
df.loc[0:3,["A","B"]]
# Out:
#            A    B
# 0 2018-11-01  0.0
# 1 2018-11-02  1.0
# 2 2018-11-03  2.0
# 3 2018-11-04  3.0

# %%
#低一列
df.loc[0]
# Out:
# A    2018-11-01 00:00:00
# B                      0
# C                      3
# D                     测试
# E                    foo
# Name: 0, dtype: object

# %%
df.loc[2,["A","B"]]
# Out:
# A    2018-11-03 00:00:00
# B                      2
# Name: 2, dtype: object

# %%
df.loc[0,["B","C","D"]]
# Out:
# B     0
# C     3
# D    测试
# Name: 0, dtype: object

# %%
df.iloc[3]
# Out:
# A    2018-11-04 00:00:00
# B                      3
# C                      3
# D                     训练
# E                    foo
# Name: 3, dtype: object

# %%
df.iloc[1:3,0:2]
# Out:
#            A    B
# 1 2018-11-02  1.0
# 2 2018-11-03  2.0

# %% [markdown]
# 元组可以求和，当元祖是由列表构成，可以改列表，
# 元组比列表运算速度更快，同时起到保护作用
# 列表可以和元组相互转换

# %% [markdown]
# # 1,3 根据布尔索引来索引

# %%
df[df.B>1]
# Out:
#            A    B  C   D    E
# 2 2018-11-03  2.0  3  测试  foo
# 3 2018-11-04  3.0  3  训练  foo

# %%
df[df>0]
# Out:
#            A    B  C   D    E
# 0 2018-11-01  NaN  3  测试  foo
# 1 2018-11-02  1.0  3  训练  foo
# 2 2018-11-03  2.0  3  测试  foo
# 3 2018-11-04  3.0  3  训练  foo

# %%
df
# Out:
#            A    B  C   D    E
# 0 2018-11-01  0.0  3  测试  foo
# 1 2018-11-02  1.0  3  训练  foo
# 2 2018-11-03  2.0  3  测试  foo
# 3 2018-11-04  3.0  3  训练  foo

# %%
df[df["B"]>1]
# Out:
#            A    B  C   D    E
# 2 2018-11-03  2.0  3  测试  foo
# 3 2018-11-04  3.0  3  训练  foo

# %%
df[df.loc[:,"B"]>1]
# Out:
#            A    B  C   D    E
# 2 2018-11-03  2.0  3  测试  foo
# 3 2018-11-04  3.0  3  训练  foo

# %%
df[df.iloc[:,1]>1]
# Out:
#            A    B  C   D    E
# 2 2018-11-03  2.0  3  测试  foo
# 3 2018-11-04  3.0  3  训练  foo

# %% [markdown]
# # 改为二元值

# %%
dff=df>0
dff
# Out:
# False

# %%
df==0
# Out:
# True

# %% [markdown]
# # 用isin函数进行过滤转换

# %%
dff[dff.isin([False])]
# Out:
#     A    B   C   D   E
# 0 NaN  0.0 NaN NaN NaN
# 1 NaN  NaN NaN NaN NaN
# 2 NaN  NaN NaN NaN NaN
# 3 NaN  NaN NaN NaN NaN

# %%
df.isin([0])
#0在里为true，不为零为false
# Out:
#        A      B      C      D      E
# 0  False   True  False  False  False
# 1  False  False  False  False  False
# 2  False  False  False  False  False
# 3  False  False  False  False  False

# %%
dff=df.copy()

# %%
dff["E"]=["one","two","three","four"]
# Out:
#            A    B  C   D      E
# 0 2018-11-01  0.0  3  测试    one
# 1 2018-11-02  1.0  3  训练    two
# 2 2018-11-03  2.0  3  测试  three
# 3 2018-11-04  3.0  3  训练   four

# %% [markdown]
# # https://blog.csdn.net/lzw2016/article/details/80472649

# %%
dff[dff["E"].isin(["two","four"])]
# Out:
#            A    B  C   D     E
# 1 2018-11-02  1.0  3  训练   two
# 3 2018-11-04  3.0  3  训练  four

# %%
df=pd.DataFrame(np.random.randn(4,4),columns=['A','B','C','D'])
df['E']=['a','a','c','b']
df.D=[0,1,0,2]
df
#df[df.isin({'D':[0,3],'E':['a','d']})]
df[df.isin([0])]
# Out:
#     A   B   C    D    E
# 0 NaN NaN NaN  0.0  NaN
# 1 NaN NaN NaN  NaN  NaN
# 2 NaN NaN NaN  0.0  NaN
# 3 NaN NaN NaN  NaN  NaN

# %%
df[df.isin(['a'])]
# Out:
#     A   B   C   D    E
# 0 NaN NaN NaN NaN    a
# 1 NaN NaN NaN NaN    a
# 2 NaN NaN NaN NaN  NaN
# 3 NaN NaN NaN NaN  NaN

# %%
df.E.isin(['a','c'])
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# Name: E, dtype: bool

# %%
df[df.isin(['b'])]
# Out:
#     A   B   C   D    E
# 0 NaN NaN NaN NaN  NaN
# 1 NaN NaN NaN NaN  NaN
# 2 NaN NaN NaN NaN  NaN
# 3 NaN NaN NaN NaN    b

# %%
df[df.isin([-5,5])]
# Out:
#     A   B   C   D    E
# 0 NaN NaN NaN NaN  NaN
# 1 NaN NaN NaN NaN  NaN
# 2 NaN NaN NaN NaN  NaN
# 3 NaN NaN NaN NaN  NaN

# %% [markdown]
# # python如何给列赋值

# %%
dfcopy=df.copy()
dfcopy.E
# Out:
# 0    foo
# 1    foo
# 2    foo
# 3    foo
# Name: E, dtype: object

# %% [markdown]
# ### 给特定单元格赋值

# %%
df.loc[0,"C"]=0
df
# Out:
#            A    B  C   D    E
# 0 2018-11-01  0.0  0  测试  foo
# 1 2018-11-02  1.0  3  训练  foo
# 2 2018-11-03  2.0  3  测试  foo
# 3 2018-11-04  3.0  3  训练  foo

# %%
df.loc[1,"C"]=0
df
# Out:
#            A    B  C   D    E
# 0 2018-11-01  0.0  0  测试  foo
# 1 2018-11-02  1.0  0  训练  foo
# 2 2018-11-03  2.0  3  测试  foo
# 3 2018-11-04  3.0  3  训练  foo

# %% [markdown]
# ### 增加列

# %%
df.loc[:,"G"]= np.array([5]*len(df))
df
# Out:
#            A    B  C   D    E  G
# 0 2018-11-01  0.0  3  测试  foo  5
# 1 2018-11-02  1.0  3  训练  foo  5
# 2 2018-11-03  2.0  3  测试  foo  5
# 3 2018-11-04  3.0  3  训练  foo  5

# %% [markdown]
# # 删除和索引

# %%
#df.drop("G",axis=1,inplace=True)
df
# Out:
#            A    B  C   D    E
# 0 2018-11-01  0.0  3  测试  foo
# 1 2018-11-02  1.0  3  训练  foo
# 2 2018-11-03  2.0  3  测试  foo
# 3 2018-11-04  3.0  3  训练  foo

# %%
#m默认axis=0，默认按行删除
#df.drop([0,1],inplace=True)
df
# Out:
#            A    B  C   D    E
# 2 2018-11-03  2.0  3  测试  foo
# 3 2018-11-04  3.0  3  训练  foo

# %%
#删掉多列
delcol=[2,3]
df.drop(df.columns[delcol],axis=1,inplace=True)
#df.drop(df.columns[[2,3]],axis=1,inplace=True)
df
# Out:
#            A    B    E
# 2 2018-11-03  2.0  foo
# 3 2018-11-04  3.0  foo

# %%
#将制定列为索引
df.set_index("A",inplace=True)
df
# Out:
#             index    B    E
# A
# 2018-11-03      0  2.0  foo
# 2018-11-04      1  3.0  foo

# %%
df.reset_index(level=0,inplace=True)
df
# Out:
#            A  index    B    E
# 0 2018-11-03      0  2.0  foo
# 1 2018-11-04      1  3.0  foo

# %% [markdown]
# # 3.缺失值处理

# %%
NumRows=7
dates=pd.date_range("20181101",periods=NumRows)
#df=pd.DataFrame(np.random.randn(NumRows,4),index=dates,columns=["A","B","C","D"])
df=pd.DataFrame(np.random.randn(NumRows,4),index=dates,columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2018-11-01 -0.939541  0.327031 -0.635756  0.127638
# 2018-11-02  1.102845 -0.541678  0.592630  0.333115
# 2018-11-03  0.824062  0.486179  1.291324  0.976124
# 2018-11-04  0.203279 -0.909880  1.255950 -0.569601
# 2018-11-05  1.081479  0.075937 -1.095675  0.453911
# 2018-11-06 -0.510440 -1.527625  0.674263  2.373811
# 2018-11-07 -0.039474 -0.545049 -0.785446  0.345697

# %%
df1=df.reindex(index=dates[0:4],columns=list(df.columns)+["E"])
df1.loc[:,"F"]=1
df1
# Out:
#                    A         B         C         D   E  F
# 2018-11-01 -0.939541  0.327031 -0.635756  0.127638 NaN  1
# 2018-11-02  1.102845 -0.541678  0.592630  0.333115 NaN  1
# 2018-11-03  0.824062  0.486179  1.291324  0.976124 NaN  1
# 2018-11-04  0.203279 -0.909880  1.255950 -0.569601 NaN  1

# %%
#dropna()可以删除缺失值，但返回一个新的数据结构
df1.dropna(how="all",axis=1)
# Out:
#                    A         B         C         D  F
# 2018-11-01 -0.939541  0.327031 -0.635756  0.127638  1
# 2018-11-02  1.102845 -0.541678  0.592630  0.333115  1
# 2018-11-03  0.824062  0.486179  1.291324  0.976124  1
# 2018-11-04  0.203279 -0.909880  1.255950 -0.569601  1

# %%
df1.dropna(how="any",axis=0)
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E, F]
# Index: []

# %%
df1.dropna(how="any",axis=1)
# Out:
#                    A         B         C         D  F
# 2018-11-01 -0.939541  0.327031 -0.635756  0.127638  1
# 2018-11-02  1.102845 -0.541678  0.592630  0.333115  1
# 2018-11-03  0.824062  0.486179  1.291324  0.976124  1
# 2018-11-04  0.203279 -0.909880  1.255950 -0.569601  1

# %% [markdown]
# ### any 对有缺失值的就删掉
# ### all 对所有都是缺失值的再删掉

# %%
df1=df.reindex(index=dates[0:4],columns=list(df.columns)+["E"])
df1.loc[:,"F"]=1
#用相同数据进行填充
df1.fillna(value=5)
# Out:
#                    A         B         C         D    E  F
# 2018-11-01  0.086344  0.662033  2.978981 -0.995973  5.0  1
# 2018-11-02  0.906169 -2.113463  0.197207 -1.293681  5.0  1
# 2018-11-03 -0.941848  0.342686 -0.470150 -1.965719  5.0  1
# 2018-11-04  1.205872 -0.781671  0.086076 -1.612581  5.0  1

# %%
df1=df.reindex(index=dates[0:4])
df1
# Out:
#                    A         B         C         D
# 2018-11-01  0.086344  0.662033  2.978981 -0.995973
# 2018-11-02  0.906169 -2.113463  0.197207 -1.293681
# 2018-11-03 -0.941848  0.342686 -0.470150 -1.965719
# 2018-11-04  1.205872 -0.781671  0.086076 -1.612581

# %%
df1.fillna(value={"E":5},inplace=True)
df1
# Out:
#                    A         B         C         D    E  F
# 2018-11-01  0.086344  0.662033  2.978981 -0.995973  5.0  1
# 2018-11-02  0.906169 -2.113463  0.197207 -1.293681  5.0  1
# 2018-11-03 -0.941848  0.342686 -0.470150 -1.965719  5.0  1
# 2018-11-04  1.205872 -0.781671  0.086076 -1.612581  5.0  1

# %%
df1.fillna(value={"D":2},inplace=True)
df1
# Out:
#                    A         B         C         D    E  F
# 2018-11-01  0.086344  0.662033  2.978981 -0.995973  5.0  1
# 2018-11-02  0.906169 -2.113463  0.197207 -1.293681  5.0  1
# 2018-11-03 -0.941848  0.342686 -0.470150 -1.965719  5.0  1
# 2018-11-04  1.205872 -0.781671  0.086076 -1.612581  5.0  1

# %% [markdown]
# # 判断是否是缺失值

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      E      F
# 2018-11-01  False  False  False  False  False  False
# 2018-11-02  False  False  False  False  False  False
# 2018-11-03  False  False  False  False  False  False
# 2018-11-04  False  False  False  False  False  False

# %% [markdown]
# ### 对序列Series和数据框架DataFrame都可以使用方法，调用方法时自动忽略缺失数据

# %%
s=pd.Series([1,3,4,5,np.nan,6,8],index=dates).shift(2)
s
# Out:
# 2018-11-01    NaN
# 2018-11-02    NaN
# 2018-11-03    1.0
# 2018-11-04    3.0
# 2018-11-05    4.0
# 2018-11-06    5.0
# 2018-11-07    NaN
# Freq: D, dtype: float64

# %%
s=pd.Series([1,3,4,5,np.nan,6,8],index=dates).shift(-1)
s
# Out:
# 2018-11-01    3.0
# 2018-11-02    4.0
# 2018-11-03    5.0
# 2018-11-04    NaN
# 2018-11-05    6.0
# 2018-11-06    8.0
# 2018-11-07    NaN
# Freq: D, dtype: float64

# %%
#删除换行符
s.apply(str.strip)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-c9ad88b678e7> in <module>
# ----> 1 s.apply(str.strip)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# TypeError: descriptor 'strip' requires a 'str' object but received a 'float'

# %% [markdown]
# # 删除空格

# %%
s.apply(str.strip)
#横向制表符 \t
#纵向制表符 \v
#h换行符 \n 
#转义字符串
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-a80e2f3954ce> in <module>
# ----> 1 s.apply(str.strip)
#       2 #横向制表符 \t
#       3 #纵向制表符 \v
#       4 #h换行符 \n
#       5 #转义字符串
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# TypeError: descriptor 'strip' requires a 'str' object but received a 'int'

# %% [markdown]
# # 大小写处理

# %%
s=pd.Series(["Data science","Statistic","mathmatics"])
s.apply(str.lower)
# Out:
# 0    data science
# 1       statistic
# 2      mathmatics
# dtype: object

# %%
s.apply(str.upper)
# Out:
# 0    DATA SCIENCE
# 1       STATISTIC
# 2      MATHMATICS
# dtype: object

# %%
len(s)
# Out:
# 3

# %% [markdown]
# # 分类统计

# %%
s=pd.Series(np.random.randint(0,7,size=10))
s
# Out:
# 0    1
# 1    6
# 2    4
# 3    6
# 4    3
# 5    5
# 6    2
# 7    3
# 8    1
# 9    6
# dtype: int32

# %%
s.value_counts()
# Out:
# Statistic       1
# Data science    1
# mathmatics      1
# dtype: int64

# %%
#每一列的平均值
df.mean()
# Out:
# A   -0.260542
# B   -0.642584
# C    0.134274
# D   -1.211404
# dtype: float64

# %%
#每一行的平均值
df.mean(1)
# Out:
# 2018-11-01    0.682846
# 2018-11-02   -0.575942
# 2018-11-03   -0.758758
# 2018-11-04   -0.275576
# 2018-11-05   -1.407423
# 2018-11-06   -0.098419
# 2018-11-07   -1.032175
# Freq: D, dtype: float64

# %%
df.apply(np.cumsum)
#累加函数
# Out:
#                    A         B         C         D
# 2018-11-01  0.086344  0.662033  2.978981 -0.995973
# 2018-11-02  0.992512 -1.451430  3.176188 -2.289654
# 2018-11-03  0.050664 -1.108744  2.706038 -4.255373
# 2018-11-04  1.256536 -1.890415  2.792115 -5.867954
# 2018-11-05 -1.780037 -2.234260  3.207527 -8.532641
# 2018-11-06 -2.105972 -3.071180  3.059233 -7.615169
# 2018-11-07 -1.823797 -4.498086  0.939920 -8.479828

# %%
#求极差
df.apply(lambda x: x.max()-x.min())
# Out:
# A    4.242444
# B    2.775496
# C    5.098293
# D    3.582160
# dtype: float64

# %%
#利用append增加一些行
df2=pd.DataFrame(np.random.randn(4,4),columns=["A","B","C","D"])
s=df2.iloc[3]
#df2.append(s)
#对index进行重排
df2.append(s,ignore_index=True)
# Out:
#           A         B         C         D
# 0 -0.620695 -0.715402  0.262069 -0.073201
# 1 -0.396139 -0.210335 -0.990935 -0.162645
# 2 -1.120826 -0.236471 -1.034110  0.410724
# 3 -1.786098  1.235456 -0.192653  0.973055
# 4 -1.786098  1.235456 -0.192653  0.973055

# %%
s=pd.Series(np.random.randint(0,7,(2.5)))
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-f74a58be1c86> in <module>
# ----> 1 s=pd.Series(np.random.randint(0,7,(2.5)))
#       2 s
#
# mtrand.pyx in mtrand.RandomState.randint()
#
# mtrand.pyx in mtrand.RandomState.randint()
#
# randint_helpers.pxi in mtrand._rand_int32()
#
# TypeError: 'float' object cannot be interpreted as an integer

# %% [markdown]
# # 3.1数据合并

# %% [markdown]
# ### 用concat

# %%
df=pd.DataFrame(np.random.randn(10,4))
pieces=[df[:3],df[3:7],df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -1.360724 -0.589943  0.638320 -0.229319
# 1 -1.006034 -0.836856  0.342046 -1.047602
# 2 -1.224672  1.446633 -3.126485  0.082200
# 3 -0.086881  0.533494  0.239031 -0.534548
# 4 -1.180868 -0.521425  1.269064  1.477258
# 5  0.256129 -0.127392  1.551726 -0.907636
# 6  0.029583  0.990639  0.557074 -0.329775
# 7  1.413365  0.104472  0.088448 -0.567480
# 8  1.419517 -0.426453 -2.475546  0.700912
# 9  1.891676  1.244229 -0.928445  1.147020

# %% [markdown]
# ### 用merge进行合并

# %%
left=pd.DataFrame({'key':["foo","foo"],"lval":[1,2]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right=pd.DataFrame({'key':["foo","foo"],"lval":[3,6]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
pd.merge(left,right,on="key")
# Out:
#    key  lval_x  lval_y
# 0  foo       1       3
# 1  foo       1       6
# 2  foo       2       3
# 3  foo       2       6

# %%
left=pd.DataFrame({'key':["foo","bar"],"lval":[1,2]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right=pd.DataFrame({'key':["foo","bar"],"lval":[3,6]})
right
# Out:
#    key  lval
# 0  foo     3
# 1  bar     6

# %%
pd.merge(left,right,on="key")
# Out:
#    key  lval_x  lval_y
# 0  foo       1       3
# 1  bar       2       6

# %%
#当索引不一致的时候，如何按列合并
pd.concat([df1,df2],axis=1,ignoreindex=True)

# %%
df1.reset_index(drop=True,inplace=True)
df2.reset_index(drop=True,inplace=True)
#后面可以正确得到这样的合并

# %% [markdown]
# # 3.2 按组聚类

# %%
df=pd.DataFrame({"A":["foo","bar","foo","bar","foo","bar","foo","bar"],
                "B":["one","one","two","three","two","two","one","three"],
                "C":np.random.randn(8),
                 "D":np.random.randn(8),})
df
# Out:
#      A      B         C         D
# 0  foo    one  1.428362  0.802736
# 1  bar    one -0.839688 -0.353715
# 2  foo    two  1.043688  0.576249
# 3  bar  three -0.648969  0.263594
# 4  foo    two -0.789188 -0.243425
# 5  bar    two  0.054895 -0.157527
# 6  foo    one  3.522117  0.035859
# 7  bar  three -1.289257 -0.183018

# %%
df.groupby("A").sum()
#以A为坐标，求各个分类的平均值
# Out:
#             C         D
# A
# bar -2.723019 -0.430667
# foo  5.204978  1.171418

# %%
df.groupby(["A","B"]).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.839688 -0.353715
#     three -1.938226  0.080575
#     two    0.054895 -0.157527
# foo one    4.950478  0.838595
#     two    0.254500  0.332823

# %%
df.groupby(["A","B"]).mean()
# Out:
#                   C         D
# A   B
# bar one   -0.839688 -0.353715
#     three -0.969113  0.040288
#     two    0.054895 -0.157527
# foo one    2.475239  0.419297
#     two    0.127250  0.166412

# %% [markdown]
# # zip

# %%
aaa=["A","B","C"]
print(aaa)
# Out:
# ['A', 'B', 'C']

# %%
print(zip(aaa[:,-1],aaa[1,;]))
# Out:
#   File "<ipython-input-60-f634beb566c0>", line 1
#     print(zip(aaa[:,-1],aaa[1,;]))
#                               ^
# SyntaxError: invalid syntax

# %%
nums=["flower","flow","flight"]
for i in zip(*nums):
    print(i)
#只运行到位数微笑的
# Out:
# ('f', 'f', 'f')
# ('l', 'l', 'l')
# ('o', 'o', 'i')
# ('w', 'w', 'g')

# %% [markdown]
# # 3.3 重新排列组合

# %%
tuples=list(zip(*[["bar","bar","baz","baz","foo","foo","qux","qux"],
               ["one","two","one","two","one","two","one","two"]]))
tuples
#之后重新排列，那样单个里面列的是均值
#只想知道这些组合的数据
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
[1,2]*5+[2,4]*2
# Out:
# [1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 2, 4, 2, 4]

# %%
#等价于以下的

# %%
m=[[1,2],[3,4],[5,6]]
n=[[2,4],[6,8],[10,12]]
zip(m,n)
list(zip(m,n))
# Out:
# [([1, 2], [2, 4]), ([3, 4], [6, 8]), ([5, 6], [10, 12])]

# %%
list(zip([m,n]))
# Out:
# [([[1, 2], [3, 4], [5, 6]],), ([[2, 4], [6, 8], [10, 12]],)]

# %%
import numpy as np
index=pd.MultiIndex.from_tuples(tuples,names=["first","second"])
df=pd.DataFrame(np.random.randn(8,2),index=index,columns=["A","B"])
df
# Out:
#                      A         B
# first second
# bar   one     0.575848 -2.118087
#       two    -1.098833 -0.831880
# baz   one     0.658487 -2.393657
#       two     0.520845  0.714972
# foo   one    -0.500614  1.245833
#       two    -0.670916 -0.772472
# qux   one     0.524303 -0.465962
#       two     0.198211  0.829963

# %%
list(*zip([m,n]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-53b46877d6d8> in <module>
# ----> 1 list(*zip([m,n]))
#
# TypeError: list expected at most 1 arguments, got 2

# %%
print(*zip(m,n))
# Out:
# ([1, 2], [2, 4]) ([3, 4], [6, 8]) ([5, 6], [10, 12])

# %%
list(zip(*zip(m,n)))
# Out:
# [([1, 2], [3, 4], [5, 6]), ([2, 4], [6, 8], [10, 12])]

# %%
#逆操作
*zip(m,n)
# Out:
#   File "cell_name", line 5
# SyntaxError: can't use starred expression here

# %%
l=["a","b","c"]
zip (l[:,-1],l[1,:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-39b71e9404eb> in <module>
#       1 l=["a","b","c"]
# ----> 2 zip (l[:,-1],l[1,:])
#
# TypeError: list indices must be integers or slices, not tuple

# %%
index=pd.MultiIndex.from_tuples(tuples,names=["first","second"])
df=pd.DataFrame(np.random.randn(8,2),index=index,columns=["A","B"])
df2=df[:4]
df2
# Out:
#                      A         B
# first second
# bar   bar    -0.232460  0.498819
#       bar    -1.237053 -0.192465
# baz   baz     0.339636  1.552113
#       baz    -0.952378  0.369718

# %% [markdown]
# ## 解压缩unpack

# %%
#默认按照最后一个水平进行逆操作
stacked=df.stack()
stacked
# Out:
# first  second
# bar    one     A    0.575848
#                B   -2.118087
#        two     A   -1.098833
#                B   -0.831880
# baz    one     A    0.658487
#                B   -2.393657
#        two     A    0.520845
#                B    0.714972
# foo    one     A   -0.500614
#                B    1.245833
#        two     A   -0.670916
#                B   -0.772472
# qux    one     A    0.524303
#                B   -0.465962
#        two     A    0.198211
#                B    0.829963
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.575848 -2.118087
#       two    -1.098833 -0.831880
# baz   one     0.658487 -2.393657
#       two     0.520845  0.714972
# foo   one    -0.500614  1.245833
#       two    -0.670916 -0.772472
# qux   one     0.524303 -0.465962
#       two     0.198211  0.829963

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.575848 -1.098833
#       B -2.118087 -0.831880
# baz   A  0.658487  0.520845
#       B -2.393657  0.714972
# foo   A -0.500614 -0.670916
#       B  1.245833 -0.772472
# qux   A  0.524303  0.198211
#       B -0.465962  0.829963

# %%
stacked.unstack(0)
# Out:
# first          bar       baz       foo       qux
# second
# one    A  0.575848  0.658487 -0.500614  0.524303
#        B -2.118087 -2.393657  1.245833 -0.465962
# two    A -1.098833  0.520845 -0.670916  0.198211
#        B -0.831880  0.714972 -0.772472  0.829963

# %% [markdown]
# # 数据透视表

# %%
df=pd.DataFrame({"A":["one","one","two","Three"]*3,
                 "B":["A","B","C"]*4,
                "C":["foo","foo","foo","bar","bar","var"]*2,
               "D":np.random.randn(12),
                "E":np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  1.395366 -1.080119
# 1     one  B  foo -0.262721 -0.057066
# 2     two  C  foo  0.788830 -2.078784
# 3   Three  A  bar -1.415556  0.445415
# 4     one  B  bar  1.111892 -0.178533
# 5     one  C  var -1.735027 -0.155198
# 6     two  A  foo  1.078902  0.482775
# 7   Three  B  foo  0.134291  0.415295
# 8     one  C  foo -0.171328  0.525442
# 9     one  A  bar -0.070720  0.049654
# 10    two  B  bar -0.080793  0.174969
# 11  Three  C  var -0.475574 -1.241589

# %%
table=pd.pivot_table(df,values="D",index=["A","B"],columns=["C"],aggfunc=np.sum)
table
# Out:
# C             bar       foo       var
# A     B
# Three A -1.415556       NaN       NaN
#       B       NaN  0.134291       NaN
#       C       NaN       NaN -0.475574
# one   A -0.070720  1.395366       NaN
#       B  1.111892 -0.262721       NaN
#       C       NaN -0.171328 -1.735027
# two   A       NaN  1.078902       NaN
#       B -0.080793       NaN       NaN
#       C       NaN  0.788830       NaN

# %%
df.isin([0])
# Out:
#         A      B      C      D      E
# 0   False  False  False  False  False
# 1   False  False  False  False  False
# 2   False  False  False  False  False
# 3   False  False  False  False  False
# 4   False  False  False  False  False
# 5   False  False  False  False  False
# 6   False  False  False  False  False
# 7   False  False  False  False  False
# 8   False  False  False  False  False
# 9   False  False  False  False  False
# 10  False  False  False  False  False
# 11  False  False  False  False  False

# %% [markdown]
# # 3.5 分类数据

# %%
import pandas as pd
df=pd.DataFrame({"id":[1,2,3,4,5,6],"raw_grade":["a","b","b","a","a","e"]})
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df["grade"]=df["raw_grade"].astype("category")
#其他类别
#np.int,"int31","flout64","string"
df
# Out:
#    id raw_grade grade
# 0   1         a     a
# 1   2         b     b
# 2   3         b     b
# 3   4         a     a
# 4   5         a     a
# 5   6         e     e

# %% [markdown]
# ## 重新改名

# %%
#a按照顺序来,只有分类数据才可以改名
df["grade"].cat.categories = ["very good","good","very bad"]
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
df["grade"].cat.set_categories = ["very bad","bad","medium","good","very good"]

df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (3, object): [very good, good, very bad]

# %%
#这个时候再对这个分类数据进行排序就不会按照字典顺序
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good
# 1   2         b       good
# 2   3         b       good
# 5   6         e   very bad

# %%
#把这些分类数据按组进行聚类的时候，即使这个类以后没有任何数值，也会显示出一个空的类别
df.groupby("grade").size()
# Out:
# grade
# very good    3
# good         2
# very bad     1
# dtype: int64

# %% [markdown]
# ## 排序

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good
# 1   2         b       good
# 2   3         b       good
# 5   6         e   very bad

# %% [markdown]
# ## 统计频次

# %%
df.groupby("grade").size()
# Out:
# grade
# very good    3
# good         2
# very bad     1
# dtype: int64

# %% [markdown]
# # 数据的导入和输出

# %%
#获取当前路径
import os
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo'

# %%
df.to_csv("foo.csv")

# %%
df2=pd.DataFrame({"id":[1,2,3,4,np.NaN,6],"raw_grade":["a","b","b","a","a","e"]})
df2.to_csv("nan.csv")

# %%
#默认用逗号分隔,改问问好分隔，默认缺失值为 ，现改为NA表示,,改为保留两位小数，没有列名,没有索引
#df.to_csv("foolish.csv",na_rep="NA",float_format="%.2f",header=0,index=0)
#df.to_csv("fool.csv",sep="?",na_rep="NA",float_format="%.2f",header=0,index=0)
#df.to_csv("foo.csv",sep="?",narep="NA",float_format="% 2f",heder=0,index=0)

# %%
#excel多了给每张表的命名
df.to_excel("foo.xlsx",sheet_name="Foo")

# %%
#指定列为索引列，将缺失值赋值为NA
pd_tmp=pd.read_excel("foo.xlsx","Foo",index_col=None,na_Value=["NA"])

# %% [markdown]
# # 对Minard文件进行分析处理

# %%
minard=pd.read_csv("Minard.csv",encoding="gbk")
minard
# Out:
#    longitude  latitude         city direction  survivors
# 0       32.0      54.8     Smolensk   Advance     145000
# 1       33.2      54.9  Dorogobouge   Advance     140000
# 2       34.4      55.5        Chjat   Advance     127100
# 3       37.6      55.8       Moscou   Advance     100000
# 4       34.3      55.2        Wixma   Retreat      55000
# 5       32.0      54.6     Smolensk   Retreat      24000
# 6       30.4      54.4       Orscha   Retreat      20000
# 7       26.8      54.3    Moiodexno   Retreat      12000

# %%
#绘制表格大小
[len(minard.index),len(minard.columns)]
# Out:
# [8, 5]

# %%
#表格列标签
minard.columns
# Out:
# Index(['longitude', 'latitude', 'city', 'direction', 'survivors'], dtype='object')

# %%
#改列名称
minard.rename(columns={"city":"city name"},inplace=True)
minard
# Out:
#    longitude  latitude    city name direction  survivors
# 0       32.0      54.8     Smolensk   Advance     145000
# 1       33.2      54.9  Dorogobouge   Advance     140000
# 2       34.4      55.5        Chjat   Advance     127100
# 3       37.6      55.8       Moscou   Advance     100000
# 4       34.3      55.2        Wixma   Retreat      55000
# 5       32.0      54.6     Smolensk   Retreat      24000
# 6       30.4      54.4       Orscha   Retreat      20000
# 7       26.8      54.3    Moiodexno   Retreat      12000

# %%
#提取单列
minard["survivors"]
# Out:
# 0    145000
# 1    140000
# 2    127100
# 3    100000
# 4     55000
# 5     24000
# 6     20000
# 7     12000
# Name: survivors, dtype: int64

# %%
minard.loc[:,"survivors"]
# Out:
# 0    145000
# 1    140000
# 2    127100
# 3    100000
# 4     55000
# 5     24000
# 6     20000
# 7     12000
# Name: survivors, dtype: int64

# %%
minard.iloc[:,4]
# Out:
# 0    145000
# 1    140000
# 2    127100
# 3    100000
# 4     55000
# 5     24000
# 6     20000
# 7     12000
# Name: survivors, dtype: int64

# %%
minard.iloc[0,4]
# Out:
# 145000

# %%
#列操作
initial=minard.iloc[0,4]
initial
psurviving = minard.iloc[:,4] / initial
psurviving
# Out:
# 0    1.000000
# 1    0.965517
# 2    0.876552
# 3    0.689655
# 4    0.379310
# 5    0.165517
# 6    0.137931
# 7    0.082759
# Name: survivors, dtype: float64

# %%
minard["percent surviving"]=psurviving
minard
# Out:
#    longitude  latitude    city name direction  survivors  percent surviving
# 0       32.0      54.8     Smolensk   Advance     145000           1.000000
# 1       33.2      54.9  Dorogobouge   Advance     140000           0.965517
# 2       34.4      55.5        Chjat   Advance     127100           0.876552
# 3       37.6      55.8       Moscou   Advance     100000           0.689655
# 4       34.3      55.2        Wixma   Retreat      55000           0.379310
# 5       32.0      54.6     Smolensk   Retreat      24000           0.165517
# 6       30.4      54.4       Orscha   Retreat      20000           0.137931
# 7       26.8      54.3    Moiodexno   Retreat      12000           0.082759

# %%
#加百分号
minard['percent surviving']=pd.Series(["{0:.2f}%".format(val*100)
                                       for val in minard['percent surviving']])
minard
# Out:
#    longitude  latitude    city name direction  survivors percent surviving
# 0       32.0      54.8     Smolensk   Advance     145000           100.00%
# 1       33.2      54.9  Dorogobouge   Advance     140000            96.55%
# 2       34.4      55.5        Chjat   Advance     127100            87.66%
# 3       37.6      55.8       Moscou   Advance     100000            68.97%
# 4       34.3      55.2        Wixma   Retreat      55000            37.93%
# 5       32.0      54.6     Smolensk   Retreat      24000            16.55%
# 6       30.4      54.4       Orscha   Retreat      20000            13.79%
# 7       26.8      54.3    Moiodexno   Retreat      12000             8.28%

# %%
minard[["longitude","latitude"]]
# Out:
#    longitude  latitude
# 0       32.0      54.8
# 1       33.2      54.9
# 2       34.4      55.5
# 3       37.6      55.8
# 4       34.3      55.2
# 5       32.0      54.6
# 6       30.4      54.4
# 7       26.8      54.3

# %%
minard.loc[:,["longitude","latitude"]]
# Out:
#    longitude  latitude
# 0       32.0      54.8
# 1       33.2      54.9
# 2       34.4      55.5
# 3       37.6      55.8
# 4       34.3      55.2
# 5       32.0      54.6
# 6       30.4      54.4
# 7       26.8      54.3

# %%
#drop方法实际不改变数据框，而是提取被删除数据框后剩下的部分，del方法会直接删除数据框中的制定数据
minard1=minard.drop(minard[["longitude","latitude","direction"]],axis=1,inplace=False)
minard
# Out:
#    longitude  latitude    city name direction  survivors percent surviving
# 0       32.0      54.8     Smolensk   Advance     145000           100.00%
# 1       33.2      54.9  Dorogobouge   Advance     140000            96.55%
# 2       34.4      55.5        Chjat   Advance     127100            87.66%
# 3       37.6      55.8       Moscou   Advance     100000            68.97%
# 4       34.3      55.2        Wixma   Retreat      55000            37.93%
# 5       32.0      54.6     Smolensk   Retreat      24000            16.55%
# 6       30.4      54.4       Orscha   Retreat      20000            13.79%
# 7       26.8      54.3    Moiodexno   Retreat      12000             8.28%

# %%
del minard["longitude"]
minard
# Out:
#    latitude    city name direction  survivors percent surviving
# 0      54.8     Smolensk   Advance     145000           100.00%
# 1      54.9  Dorogobouge   Advance     140000            96.55%
# 2      55.5        Chjat   Advance     127100            87.66%
# 3      55.8       Moscou   Advance     100000            68.97%
# 4      55.2        Wixma   Retreat      55000            37.93%
# 5      54.6     Smolensk   Retreat      24000            16.55%
# 6      54.4       Orscha   Retreat      20000            13.79%
# 7      54.3    Moiodexno   Retreat      12000             8.28%

# %% [markdown]
# # 对人口数据excel进行分析处理

# %% [markdown]
# ## 京沪人口差距比较

# %%
pd_tmp=pd.read_csv("renkou18.csv",encoding="gbk")

# %%
pd_tmp
# Out:
#         年龄  性别          全国        北京        天津        河北        山西       内蒙古  \
# 0       合计  小计  1332810869  19612368  12938693  71854210  35712101  24706291
# 1       合计   男   682329104  10126430   6907091  36430286  18338760  12838243
# 2       合计   女   650481765   9485938   6031602  35423924  17373341  11868048
# 3       0岁  小计    13786434    115882     81871    880194    345782    204151
# 4       0岁   男     7461199     60564     43546    470526    181346    107837
# 5       0岁   女     6325235     55318     38325    409668    164436     96314
# 6     1-5岁  小计    61746176    569998    379022   3897692   1477029    914675
# 7     1-5岁   男    33601367    300229    201322   2100526    775404    479554
# 8     1-5岁   女    28144809    269769    177700   1797166    701625    435121
# 9     6-9岁  小计    70881549    501269    397798   4041271   1866552   1092749
# 10    6-9岁   男    38464665    266411    212250   2168112    978796    571128
# ...

# %%
#不要列标题，跳过前两行
pd_tmp2=pd.read_csv("renkou18.csv",encoding="gbk",header=None,skiprows=2)
pd_tmp2
# Out:
#         0   1          2         3        4         5         6         7   \
# 0       合计   男  682329104  10126430  6907091  36430286  18338760  12838243
# 1       合计   女  650481765   9485938  6031602  35423924  17373341  11868048
# 2       0岁  小计   13786434    115882    81871    880194    345782    204151
# 3       0岁   男    7461199     60564    43546    470526    181346    107837
# 4       0岁   女    6325235     55318    38325    409668    164436     96314
# 5     1-5岁  小计   61746176    569998   379022   3897692   1477029    914675
# 6     1-5岁   男   33601367    300229   201322   2100526    775404    479554
# 7     1-5岁   女   28144809    269769   177700   1797166    701625    435121
# 8     6-9岁  小计   70881549    501269   397798   4041271   1866552   1092749
# 9     6-9岁   男   38464665    266411   212250   2168112    978796    571128
# 10    6-9岁   女   32416884    234858   185548   1873159    887756    521621
# ...

# %%
#不要列标题，跳过前两行
#Excel 才支持
pd_tmp3=pd.read_csv("renkou18.csv",encoding="gbk",header=None,skipfooter=2,engine="python")
pd_tmp3
# Out:
#         0   1           2         3         4         5         6         7   \
# 0       年龄  性别          全国        北京        天津        河北        山西       内蒙古
# 1       合计  小计  1332810869  19612368  12938693  71854210  35712101  24706291
# 2       合计   男   682329104  10126430   6907091  36430286  18338760  12838243
# 3       合计   女   650481765   9485938   6031602  35423924  17373341  11868048
# 4       0岁  小计    13786434    115882     81871    880194    345782    204151
# 5       0岁   男     7461199     60564     43546    470526    181346    107837
# 6       0岁   女     6325235     55318     38325    409668    164436     96314
# 7     1-5岁  小计    61746176    569998    379022   3897692   1477029    914675
# 8     1-5岁   男    33601367    300229    201322   2100526    775404    479554
# 9     1-5岁   女    28144809    269769    177700   1797166    701625    435121
# 10    6-9岁  小计    70881549    501269    397798   4041271   1866552   1092749
# ...

# %%
minard=pd.read_csv("Minard.csv",encoding="gbk")
minard
# Out:
#    longitude  latitude         city direction  survivors
# 0       32.0      54.8     Smolensk   Advance     145000
# 1       33.2      54.9  Dorogobouge   Advance     140000
# 2       34.4      55.5        Chjat   Advance     127100
# 3       37.6      55.8       Moscou   Advance     100000
# 4       34.3      55.2        Wixma   Retreat      55000
# 5       32.0      54.6     Smolensk   Retreat      24000
# 6       30.4      54.4       Orscha   Retreat      20000
# 7       26.8      54.3    Moiodexno   Retreat      12000

# %%
import pandas as pd
pop=pd.read_csv("renkou18.csv",encoding="gbk")

# %%
pop.iloc[0:9,0:7]
# Out:
#      年龄  性别          全国        北京        天津        河北        山西
# 0    合计  小计  1332810869  19612368  12938693  71854210  35712101
# 1    合计   男   682329104  10126430   6907091  36430286  18338760
# 2    合计   女   650481765   9485938   6031602  35423924  17373341
# 3    0岁  小计    13786434    115882     81871    880194    345782
# 4    0岁   男     7461199     60564     43546    470526    181346
# 5    0岁   女     6325235     55318     38325    409668    164436
# 6  1-5岁  小计    61746176    569998    379022   3897692   1477029
# 7  1-5岁   男    33601367    300229    201322   2100526    775404
# 8  1-5岁   女    28144809    269769    177700   1797166    701625

# %%
#计算表格的大小
#[0]为行数，[1] 为列数，
print(pop.shape[0],pop.shape[1],len(pop))
# Out:
# 69 34 69

# %%
pop.columns
# Out:
# Index(['年龄', '性别', '全国', '北京', '天津', '河北', '山西', '内蒙古', '辽宁', '吉林', '黑龙江',
#        '上海', '江苏', '浙江', '安徽', '福建', '江西', '山东', '河南', '湖北', '湖南', '广东', '广西',
#        '海南', '重庆', '四川', '贵州', '云南', '西藏', '陕西', '甘肃', '青海', '宁夏', '新疆'],
#       dtype='object')

# %%
pop['性别'].unique()
# Out:
# array(['小计', '男', '女'], dtype=object)

# %%
pop['年龄'].unique()
# Out:
# array(['合计', '0岁', '1-5岁', '6-9岁', '10-14岁', '15-19岁', '20-24岁', '25-29岁',
#        '30-34岁', '35-39岁', '40-44岁', '45-49岁', '50-54岁', '55-59岁',
#        '60-64岁', '65-69岁', '70-74岁', '75-79岁', '80-84岁', '85-89岁',
#        '90-94岁', '95-99岁', '100岁以上'], dtype=object)

# %%
pop1=pop[["年龄","性别","北京","上海"]]

# %%
pop2=pop1.rename(columns={"北京":"京","上海":"沪"})
pop2.head(4)
# Out:
#    年龄  性别         京         沪   change
# 0  合计  小计  19612368  23019196 -3406828
# 1  合计   男  10126430  11854916 -1728486
# 2  合计   女   9485938  11164280 -1678342
# 3  0岁  小计    115882    128222   -12340

# %%
change=pop1["北京"]-pop1["上海"]

# %%
pop1["change"]=change
pop1.head(3)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    年龄  性别        北京        上海   change
# 0  合计  小计  19612368  23019196 -3406828
# 1  合计   男  10126430  11854916 -1728486
# 2  合计   女   9485938  11164280 -1678342

# %% [markdown]
# ### 百分比

# %%
#计算两地人差的百分比
pop2['percent change'] = change/pop2["京"]
pop2['percent change']=pd.Series(pd.Series(["{0:.2f}%".format(val*100)
for val in pop2['percent change']]))
pop2.head(3)
# Out:
#    年龄  性别         京         沪   change percent change
# 0  合计  小计  19612368  23019196 -3406828        -17.37%
# 1  合计   男  10126430  11854916 -1728486        -17.07%
# 2  合计   女   9485938  11164280 -1678342        -17.69%

# %%
pop3=pop2
pop3.head(2)
# Out:
#    年龄  性别         京         沪   change percent change
# 0  合计  小计  19612368  23019196 -3406828        -17.37%
# 1  合计   男  10126430  11854916 -1728486        -17.07%

# %%
#人口变化数量降序排列
difpop3=pop3.sort_values(by="percent change",ascending=False)
difpop3.head(5)
# Out:
#         年龄  性别        京        沪  change percent change
# 19  20-24岁   男  1368039  1339673   28366          2.07%
# 18  20-24岁  小计  2633028  2620370   12658          0.48%
# 56  80-84岁   女   104854   204429  -99575        -94.97%
# 58  85-89岁   男    34359    65346  -30987        -90.19%
# 5       0岁   女    55318    60755   -5437         -9.83%

# %% [markdown]
# # 上海地区男女比

# %%
difpophu=difpop3.drop(columns=["京","change","percent change"])
#如果有inplace=true，原数据框也改变
difpophu.head(4)
# Out:
#         年龄  性别        沪
# 19  20-24岁   男  1339673
# 18  20-24岁  小计  2620370
# 56  80-84岁   女   204429
# 58  85-89岁   男    65346

# %%
allage=difpophu.sort_values(by="沪",ascending=False)
allage.head(5)
#这样排的话index是乱的
# Out:
#         年龄  性别         沪
# 0       合计  小计  23019196
# 1       合计   男  11854916
# 2       合计   女  11164280
# 18  20-24岁  小计   2620370
# 21  25-29岁  小计   2571181

# %%
#所有年龄段的合计情况
all_ages=difpophu[difpophu["年龄"]=="合计"]
all_ages
# Out:
#    年龄  性别         沪
# 2  合计   女  11164280
# 0  合计  小计  23019196
# 1  合计   男  11854916

# %%
#生成新框架计算男女性别比例
all_ages=all_ages.sort_values(by="沪",ascending=False)
all_ages=pd.DataFrame(all_ages.values,columns=all_ages.columns)
all_ages.head()
# Out:
#    年龄  性别         沪
# 0  合计  小计  23019196
# 1  合计   男  11854916
# 2  合计   女  11164280

# %%
all_ages["proportion"]=all_ages["沪"]/all_ages.loc[0,'沪']
all_ages["proportion"]=pd.Series(["{0:.2f}%".format(val*100)
                                 for val in all_ages["proportion"]])
all_ages
# Out:
#    年龄  性别         沪 proportion
# 0  合计  小计  23019196    100.00%
# 1  合计   男  11854916     51.50%
# 2  合计   女  11164280     48.50%

# %% [markdown]
# # 新生儿的男女比

# %%
infants=difpophu[difpophu["年龄"]=="0岁"]
infants
infants=infants.sort_values(by="沪",ascending=False)
infants=pd.DataFrame(infants.values,columns=infants.columns)
infants.head()
# Out:
#    年龄  性别       沪
# 0  0岁  小计  128222
# 1  0岁   男   67467
# 2  0岁   女   60755

# %%
infants["proportion"]=infants["沪"]/infants.loc[0,"沪"]
infants["proportion"]=pd.Series(["{0:.2f}%".format(val*100)
                                for val in infants["proportion"]])
infants
# Out:
#    年龄  性别       沪 proportion
# 0  0岁  小计  128222    100.00%
# 1  0岁   男   67467     52.62%
# 2  0岁   女   60755     47.38%

# %% [markdown]
# # 百岁老人男女比

# %%
hundreds=difpophu[difpophu["年龄"]=="100岁以上"]
hundreds
hundreds=hundreds.sort_values(by="沪",ascending=False)
hundreds=pd.DataFrame(hundreds.values,columns=hundreds.columns)
hundreds.head()
hundreds["proportion"]=hundreds["沪"]/hundreds.loc[0,"沪"]
hundreds["proportion"]=pd.Series(["{0:.2f}%".format(val*100)
                                for val in hundreds["proportion"]])
hundreds
# Out:
#        年龄  性别    沪 proportion
# 0  100岁以上  小计  928    100.00%
# 1  100岁以上   女  733     78.99%
# 2  100岁以上   男  195     21.01%

# %% [markdown]
# # 所有年龄段的男女比

# %%
females=difpophu[difpophu['性别']=="女"]
# Out:
#         年龄  性别        沪
# 19  20-24岁   男  1339673
# 18  20-24岁  小计  2620370
# 56  80-84岁   女   204429
# 58  85-89岁   男    65346
# 5       0岁   女    60755

# %%
females1=females[females["年龄"]!="合计"]
females2=females.sort_index(ascending=True,axis=0,inplace=False)

# %%
males=difpophu[difpophu['性别']=="男"]
males1=males[males["年龄"]!="合计"]
males2=males.sort_index(ascending=True,axis=0,inplace=False)

# %%
ratios=np.array(females2["沪"]/np.array(males2["沪"]))
ratios=pd.DataFrame({"年龄":np.array(males2["年龄"]),"f/m ratio":ratios})

# %%
ratios.sort_index(ascending=False,axis=1,inplace=False).head(3)
# Out:
#      年龄  f/m ratio
# 0    合计   0.941743
# 1    0岁   0.900514
# 2  1-5岁   0.872791

# %%
import matplotlib.pyplot as plt
plt.figure(1)
plt.plot(ratios["年龄"],ratios["f/m ratio"])
plt.ylabel("f/m ratio")
plt.xlabel("年龄")
plt.grid(True)
plt.show()

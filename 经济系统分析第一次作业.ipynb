# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["font.sans-serif"]="SimHei"
plt.rcParams["axes.unicode_minus"]=False

# %%
dff.head(5)
# Out:
#      地区 所属省份    年份      经济发展      社会进步      生态建设    综合发展指数    协调发展指数   区域  \
# 0   吉安市  江西省  2007  0.400742  0.156590  0.991830  0.499965  0.168335  江西省
# 1   新余市  江西省  2007  0.561769  0.591810  0.542749  0.564912  0.956254  江西省
# 2   南昌市  江西省  2007  0.560588  0.446923  0.955225  0.640925  0.592233  江西省
# 3   萍乡市  江西省  2007  0.534729  0.304529  0.933178  0.582875  0.461665  江西省
# 4  景德镇市  江西省  2007  0.520523  0.429720  0.935688  0.613256  0.570891  江西省
#
#    人均GDP
# 0  29888
# 1  88548
# 2  82472
# 3  52516
# 4  51561

# %%
df=dff[dff.年份 == 2007]
df1=df[df.区域 == "江西省"]
df2=df[df.区域 == "湖南省"]
df3=df[df.区域 == "湖北省"]
df4=df[df.区域 == "非城市群"]
#!/usr/bin/python
# -*- coding: UTF-8 -*-
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['font.family']='sans-serif'
#plt.scatter(df.人均GDP, df.综合发展指数, s=df.区域, c=df.区域, alpha=0.5, marker=(9, 3, 30))
plt.figure(figsize=(9,6))
zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
plt.scatter(df1.人均GDP, df1.综合发展指数,color="blue", s=300,alpha=0.6, marker=".",label=" 江西省")
plt.scatter(df2.人均GDP, df2.综合发展指数,color="red",s=40, alpha=0.6, marker=",",label=" 湖南省") 
plt.scatter(df3.人均GDP, df3.综合发展指数,color="green",s=80, alpha=0.6, marker="<",label=" 湖北省")
plt.scatter(df4.人均GDP, df4.综合发展指数,color="black", s=100,alpha=0.6, marker='*',label=" 非城市群")

plt.xlabel("GDP per person")
plt.ylabel("CDI")
plt.title("2016")

plt.legend(loc=4)
for i in range(len(df.人均GDP)):
    zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
    plt.annotate(df.地区[i], xy = (df.人均GDP[i],df.综合发展指数[i]), xytext = (df.人均GDP[i]-0.001, df.综合发展指数[i]+0.003))


plt.grid()
plt.show()

# %%
dfb=dff[dff.年份 == 2010]
df1=dfb[dfb.区域 == "江西省"]
df2=dfb[dfb.区域 == "湖南省"]
df3=dfb[dfb.区域 == "湖北省"]
df4=dfb[dfb.区域 == "非城市群"]
#!/usr/bin/python
# -*- coding: UTF-8 -*-
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['font.family']='sans-serif'
#plt.scatter(df.人均GDP, df.综合发展指数, s=df.区域, c=df.区域, alpha=0.5, marker=(9, 3, 30))
plt.figure(figsize=(5,5))
zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
plt.scatter(df1.人均GDP, df1.综合发展指数,color="blue", s=300,alpha=0.6, marker=".",label=" 江西省")
plt.scatter(df2.人均GDP, df2.综合发展指数,color="red",s=40, alpha=0.6, marker=",",label=" 湖南省")
plt.scatter(df3.人均GDP, df3.综合发展指数,color="green",s=80, alpha=0.6, marker="<",label=" 湖北省")
plt.scatter(df4.人均GDP, df4.综合发展指数,color="black", s=100,alpha=0.6, marker='*',label=" 非城市群")

plt.xlabel("GDP per person")
plt.ylabel("CDI")
plt.title("2010")

plt.legend(loc=4)
for i in range(len(df.人均GDP)):
    zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
 #  plt.annotate(df.城市[i], xy = (df.人均GDP[i],df.综合发展指数[i]), xytext = (df.人均GDP[i], df.综合发展指数[i]))


plt.grid()
plt.show()

# %%
dfb=dff[dff.年份 == 2013]
df1=dfb[dfb.区域 == "江西省"]
df2=dfb[dfb.区域 == "湖南省"]
df3=dfb[dfb.区域 == "湖北省"]
df4=dfb[dfb.区域 == "非城市群"]
#!/usr/bin/python
# -*- coding: UTF-8 -*-
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['font.family']='sans-serif'
#plt.scatter(df.人均GDP, df.综合发展指数, s=df.区域, c=df.区域, alpha=0.5, marker=(9, 3, 30))
plt.figure(figsize=(5,5))
zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
plt.scatter(df1.人均GDP, df1.综合发展指数,color="blue", s=300,alpha=0.6, marker=".",label=" 江西省")
plt.scatter(df2.人均GDP, df2.综合发展指数,color="red",s=40, alpha=0.6, marker=",",label=" 湖南省")
plt.scatter(df3.人均GDP, df3.综合发展指数,color="green",s=80, alpha=0.6, marker="<",label=" 湖北省")
plt.scatter(df4.人均GDP, df4.综合发展指数,color="black", s=100,alpha=0.6, marker='*',label=" 非城市群")

plt.xlabel("GDP per person")
plt.ylabel("CDI")
plt.title("2013")

plt.legend(loc=4)
for i in range(len(df.人均GDP)):
    zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
 #  plt.annotate(df.城市[i], xy = (df.人均GDP[i],df.综合发展指数[i]), xytext = (df.人均GDP[i], df.综合发展指数[i]))


plt.grid()
plt.show()

# %%
dfb=dff[dff.年份 == 2016]
df1=dfb[dfb.区域 == "江西省"]
df2=dfb[dfb.区域 == "湖南省"]
df3=dfb[dfb.区域 == "湖北省"]
df4=dfb[dfb.区域 == "非城市群"]
#!/usr/bin/python
# -*- coding: UTF-8 -*-
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['font.family']='sans-serif'
#plt.scatter(df.人均GDP, df.综合发展指数, s=df.区域, c=df.区域, alpha=0.5, marker=(9, 3, 30))
plt.figure(figsize=(5,5))
zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
plt.scatter(df1.人均GDP, df1.综合发展指数,color="blue", s=300,alpha=0.6, marker=".",label=" 江西省")
plt.scatter(df2.人均GDP, df2.综合发展指数,color="red",s=40, alpha=0.6, marker=",",label=" 湖南省")
plt.scatter(df3.人均GDP, df3.综合发展指数,color="green",s=80, alpha=0.6, marker="<",label=" 湖北省")
plt.scatter(df4.人均GDP, df4.综合发展指数,color="black", s=100,alpha=0.6, marker='*',label=" 非城市群")

plt.xlabel("GDP per person")
plt.ylabel("CDI")
plt.title("2016")

plt.legend(loc=4)
for i in range(len(df.人均GDP)):
    zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
 #  plt.annotate(df.城市[i], xy = (df.人均GDP[i],df.综合发展指数[i]), xytext = (df.人均GDP[i], df.综合发展指数[i]))


plt.grid()
plt.show()

# %%
width = 0.3
import numpy as np
index = np.arange(len(df1.城市))
df1=dff[dff.年份 == 2007]
df2=dff[dff.年份 == 2010]
df3=dff[dff.年份 == 2013]
df4=dff[dff.年份 == 2016]
plt.bar(index, df1.经济发展, width=width, color='yellow', label=u'x')
plt.bar(index+width, df2.经济发展, width=width, color='red', label=u'y') #　width=index+width 表示从向右x平移width的单位，刚好靠在一起
plt.xlabel(df1.城市)
plt.ylabel('x/y')
plt.title('barplot dodge')
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-240-9406cf9b2bc0> in <module>
#       8 plt.bar(index, df1.经济发展, width=width, color='yellow', label=u'x')
#       9 plt.bar(index+width, df2.经济发展, width=width, color='red', label=u'y') #　width=index+width 表示从向右x平移width的单位，刚好靠在一起
# ---> 10 plt.xlabel(df1.城市)
#      11 plt.ylabel('x/y')
#      12 plt.title('barplot dodge')
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in xlabel(xlabel, fontdict, labelpad, **kwargs)
#    3065 def xlabel(xlabel, fontdict=None, labelpad=None, **kwargs):
#    3066     return gca().set_xlabel(
# -> 3067         xlabel, fontdict=fontdict, labelpad=labelpad, **kwargs)
#    3068
#    3069
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in set_xlabel(self, xlabel, fontdict, labelpad, **kwargs)
#     263         if labelpad is not None:
# ...

# %%
df1=dff[dff.年份 == 2007]
df2=dff[dff.年份 == 2010]
df3=dff[dff.年份 == 2013]
df4=dff[dff.年份 == 2016]
#plt.scatter(df.人均GDP, df.综合发展指数, s=df.区域, c=df.区域, alpha=0.5, marker=(9, 3, 30))
plt.figure(figsize=(9,6))
zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
plt.scatter(df1.经济发展, df1.社会进步,color="red", s=100,alpha=0.5,label=" 2007")
plt.scatter(df2.经济发展, df2.社会进步,color="green",s=100, alpha=0.34,label=" 2010")
plt.scatter(df3.经济发展, df3.社会进步,color="blue",s=100, alpha=0.6,label=" 2013")
plt.scatter(df4.经济发展, df4.社会进步,color="purple", s=100,alpha=0.9,label=" 2016")

plt.xlabel("经济发展指数")
plt.ylabel("社会建设指数")
plt.title("经济发展与社会建设的关系图")

plt.legend(loc=4)
for i in range(len(df.人均GDP)):
    zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
  #  plt.annotate(dfb.城市[i], xy = (dfb.人均GDP[i],dfb.综合发展指数[i]), xytext = (dfb.人均GDP[i], dfb.综合发展指数[i]))


plt.grid()
plt.show()

# %%
df1=dff[dff.年份 == 2007]
df2=dff[dff.年份 == 2010]
df3=dff[dff.年份 == 2013]
df4=dff[dff.年份 == 2016]
#plt.scatter(df.人均GDP, df.综合发展指数, s=df.区域, c=df.区域, alpha=0.5, marker=(9, 3, 30))
plt.figure(figsize=(9,6))
zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
plt.scatter(df1.经济发展, df1.生态建设,color="red", s=100,alpha=0.5,label=" 2007")
plt.scatter(df2.经济发展, df2.生态建设,color="green",s=100, alpha=0.34,label=" 2010")
plt.scatter(df3.经济发展, df3.生态建设,color="blue",s=100, alpha=0.6,label=" 2013")
plt.scatter(df4.经济发展, df4.生态建设,color="purple", s=100,alpha=0.9,label=" 2016")

plt.xlabel("经济发展指数")
plt.ylabel("生态建设指数")
plt.title("经济发展与生态建设的关系图")

plt.legend(loc=4)
for i in range(len(df.人均GDP)):
    zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
  #  plt.annotate(dfb.城市[i], xy = (dfb.人均GDP[i],dfb.综合发展指数[i]), xytext = (dfb.人均GDP[i], dfb.综合发展指数[i]))


plt.grid()
plt.show()

# %%
$ pip install echarts-countries-pypkg
$ pip install echarts-china-provinces-pypkg
$ pip install echarts-china-cities-pypkg
$ pip install echarts-china-counties-pypkg
$ pip install echarts-china-misc-pypkg
$ pip install echarts-united-kingdom-pypkg
# Out:
#   File "<ipython-input-180-083656d94765>", line 1
#     $ pip install echarts-countries-pypkg
#     ^
# SyntaxError: invalid syntax

# %%
df1=dff[dff.年份 == 2007]
df2=dff[dff.年份 == 2010]
df3=dff[dff.年份 == 2013]
df4=dff[dff.年份 == 2016]
#plt.scatter(df.人均GDP, df.综合发展指数, s=df.区域, c=df.区域, alpha=0.5, marker=(9, 3, 30))
plt.figure(figsize=(9,6))
zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
plt.scatter(df1.综合发展指数, df1.协调发展指数,color="red", s=100,alpha=0.5,label=" 2007")
plt.scatter(df2.综合发展指数, df2.协调发展指数,color="green",s=100, alpha=0.34,label=" 2010")
plt.scatter(df3.综合发展指数, df3.协调发展指数,color="blue",s=100, alpha=0.6,label=" 2013")
plt.scatter(df4.综合发展指数, df4.协调发展指数,color="purple", s=100,alpha=0.9,label=" 2016")

plt.xlabel("综合发展指数")
plt.ylabel("协调发展指数指数")
plt.title("综合发展指数与协调发展指数的关系图")

plt.legend(loc=4)
for i in range(len(df.人均GDP)):
    zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
  #  plt.annotate(dfb.城市[i], xy = (dfb.人均GDP[i],dfb.综合发展指数[i]), xytext = (dfb.人均GDP[i], dfb.综合发展指数[i]))


plt.grid()
plt.show()

# %%
df1=dff[dff.年份 == 2007]
df2=dff[dff.年份 == 2010]
df3=dff[dff.年份 == 2013]
df4=dff[dff.年份 == 2016]
#plt.scatter(df.人均GDP, df.综合发展指数, s=df.区域, c=df.区域, alpha=0.5, marker=(9, 3, 30))
plt.figure(figsize=(12,6))
zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
plt.scatter(index, df1.协调发展指数,color="yellow", s=100,alpha=0.5,label=" 2007")
plt.scatter(index, df2.协调发展指数,color="green",s=100, alpha=0.34,label=" 2010")
plt.scatter(index, df3.协调发展指数,color="blue",s=100, alpha=0.6,label=" 2013")
plt.scatter(index, df4.协调发展指数,color="purple", s=100,alpha=0.9,label=" 2016")

plt.xlabel("城市")
plt.ylabel("协调发展指数")
plt.title("各城市协调发展指数")

plt.legend(loc=4)
for i in range(len(df.人均GDP)):
    zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
  #  plt.annotate(dfb.城市[i], xy = (dfb.人均GDP[i],dfb.综合发展指数[i]), xytext = (dfb.人均GDP[i], dfb.综合发展指数[i]))

#plt.xlabel()
plt.xticks(index,df1.城市,rotation=90)

plt.grid()
plt.show()

# %%
df1=dff[dff.年份 == 2007]
df2=dff[dff.年份 == 2010]
df3=dff[dff.年份 == 2013]
df4=dff[dff.年份 == 2016]
#plt.scatter(df.人均GDP, df.综合发展指数, s=df.区域, c=df.区域, alpha=0.5, marker=(9, 3, 30))
plt.figure(figsize=(12,6))
zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
plt.scatter(index, df1.综合发展指数,color="yellow", s=100,alpha=0.5,label=" 2007")
plt.scatter(index, df2.综合发展指数,color="green",s=100, alpha=0.34,label=" 2010")
plt.scatter(index, df3.综合发展指数,color="blue",s=100, alpha=0.6,label=" 2013")
plt.scatter(index, df4.综合发展指数,color="purple", s=100,alpha=0.9,label=" 2016")

plt.xlabel("城市")
plt.ylabel("综合发展指数")
plt.title("各城市综合发展指数")

plt.legend(loc=4)
for i in range(len(df.人均GDP)):
    zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
  #  plt.annotate(dfb.城市[i], xy = (dfb.人均GDP[i],dfb.综合发展指数[i]), xytext = (dfb.人均GDP[i], dfb.综合发展指数[i]))

#plt.xlabel()
plt.xticks(index,df1.城市,rotation=90)

plt.grid()
plt.show()

# %%
df1=dff[dff.年份 == 2007]
df2=dff[dff.年份 == 2010]
df3=dff[dff.年份 == 2013]
df4=dff[dff.年份 == 2016]
#plt.scatter(df.人均GDP, df.综合发展指数, s=df.区域, c=df.区域, alpha=0.5, marker=(9, 3, 30))
plt.figure(figsize=(12,6))
zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
plt.scatter(index, df1.协调发展指数,color="yellow", s=100,alpha=0.5,label=" 2007")
plt.scatter(index, df2.协调发展指数,color="green",s=100, alpha=0.34,label=" 2010")
plt.scatter(index, df3.协调发展指数,color="blue",s=100, alpha=0.6,label=" 2013")
plt.scatter(index, df4.协调发展指数,color="purple", s=100,alpha=0.9,label=" 2016")

plt.xlabel("城市")
plt.ylabel("经济发展")
plt.title("各城市经济发展")

plt.legend(loc=4)
for i in range(len(df.人均GDP)):
    zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
  #  plt.annotate(dfb.城市[i], xy = (dfb.人均GDP[i],dfb.综合发展指数[i]), xytext = (dfb.人均GDP[i], dfb.综合发展指数[i]))

#plt.xlabel()
plt.xticks(index,df1.城市,rotation=90)

plt.grid()
plt.show()

# %%
df1=dff[dff.年份 == 2007]
df2=dff[dff.年份 == 2010]
df3=dff[dff.年份 == 2013]
df4=dff[dff.年份 == 2016]
#plt.scatter(df.人均GDP, df.综合发展指数, s=df.区域, c=df.区域, alpha=0.5, marker=(9, 3, 30))
plt.figure(figsize=(12,6))
zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
plt.scatter(index, df1.社会进步,color="yellow", s=100,alpha=0.5,label=" 2007")
plt.scatter(index, df2.社会进步,color="green",s=100, alpha=0.34,label=" 2010")
plt.scatter(index, df3.社会进步,color="blue",s=100, alpha=0.6,label=" 2013")
plt.scatter(index, df4.社会进步,color="purple", s=100,alpha=0.9,label=" 2016")

plt.xlabel("城市")
plt.ylabel("社会进步")
plt.title("各城市社会进步")

plt.legend(loc=4)
for i in range(len(df.人均GDP)):
    zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
  #  plt.annotate(dfb.城市[i], xy = (dfb.人均GDP[i],dfb.综合发展指数[i]), xytext = (dfb.人均GDP[i], dfb.综合发展指数[i]))

#plt.xlabel()
plt.xticks(index,df1.城市,rotation=90)

plt.grid()
plt.show()

# %%
df1=dff[dff.年份 == 2007]
df2=dff[dff.年份 == 2010]
df3=dff[dff.年份 == 2013]
df4=dff[dff.年份 == 2016]
#plt.scatter(df.人均GDP, df.综合发展指数, s=df.区域, c=df.区域, alpha=0.5, marker=(9, 3, 30))
plt.figure(figsize=(12,6))
zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
plt.scatter(index, df1.环境友好,color="yellow", s=100,alpha=0.5,label=" 2007")
plt.scatter(index, df2.环境友好,color="green",s=100, alpha=0.34,label=" 2010")
plt.scatter(index, df3.环境友好,color="blue",s=100, alpha=0.6,label=" 2013")
plt.scatter(index, df4.环境友好,color="purple", s=100,alpha=0.9,label=" 2016")

plt.xlabel("城市")
plt.ylabel("生态建设")
plt.title("各城市生态建设情况")

plt.legend(loc=4)
for i in range(len(df.人均GDP)):
    zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
  #  plt.annotate(dfb.城市[i], xy = (dfb.人均GDP[i],dfb.综合发展指数[i]), xytext = (dfb.人均GDP[i], dfb.综合发展指数[i]))

#plt.xlabel()
plt.xticks(index,df1.城市,rotation=90)

plt.grid()
plt.show()

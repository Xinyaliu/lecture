# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams["font.sans-serif"]="SimHei"
plt.rcParams["axes.unicode_minus"]=False

# %%
from pyecharts import Pie
attr =["第一产业能耗", "第二产业能耗", "第三产业能耗", "居民生活用能"]
v1 =[71.2,6171.32,4291.17,1328.02]
pie2 = Pie()
pie2.add("商品B", attr, v1, center=[45, 50], is_random=False, radius=[20,65], color=["red","green","grey","blue"],rosetype='area', is_legend_show=False, is_label_show=True)
pie2.show_config()
#pie2.render(path='./上海.html')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-02a6e5db1d2a> in <module>
# ----> 1 from pyecharts import Pie
#       2 attr =["第一产业能耗", "第二产业能耗", "第三产业能耗", "居民生活用能"]
#       3 v1 =[71.2,6171.32,4291.17,1328.02]
#       4 pie2 = Pie()
#       5 pie2.add("商品B", attr, v1, center=[45, 50], is_random=False, radius=[20,65], color=["red","green","grey","blue"],rosetype='area', is_legend_show=False, is_label_show=True)
#
# ImportError: cannot import name 'Pie' from 'pyecharts' (C:\ProgramData\Anaconda3\lib\site-packages\pyecharts\__init__.py)

# %%
from pyecharts import Pie
attr =["第一产业能耗", "第二产业能耗", "第三产业能耗", "居民生活用能"]
v1 =[415,13626,3367,2203]
pie2 = Pie()
pie2.add("商品B", attr, v1, center=[45, 50], is_random=False, radius=[20,65], color=["red","green","grey","blue"],rosetype='area', is_legend_show=False, is_label_show=True)
pie2.show_config()
pie2.render(path='./浙江.html')
# Out:
# {'_index_flag': 1172401,
#  'backgroundColor': '#fff',
#  'color': ['#c23531',
#            '#2f4554',
#            '#61a0a8',
#            '#d48265',
#            '#749f83',
#            '#ca8622',
#            '#bda29a',
#            '#6e7074',
#            '#546570',
#            '#c4ccd3',
#            '#f05b72',
#            '#ef5b9c',
#            '#f47920',
#            '#905a3d',
#            '#fab27b',
#            '#2a5caa',
#            '#444693',
#            '#726930',
#            '#b2d235',
#            '#6d8346',
#            '#ac6767',
#            '#1d953f',
#            '#6950a1',
#            '#918597',
#            '#f6f5ec'],
#  'legend': [{'data': ['第一产业能耗', '第二产业能耗', '第三产业能耗', '居民生活用能'],
#              'left': 'center',
#              'orient': 'horizontal',
#              'selectedMode': 'multiple',
#              'show': False,
#              'top': 'top'}],
#  'series': [{'center': ['45%', '50%'],
#              'data': [{'name': '第一产业能耗', 'value': 415},
# ...

# %%
from pyecharts import Pie
attr =["第一产业能耗", "第二产业能耗", "第三产业能耗", "居民生活用能"]
v1 =[500,24000,4000,2553.89]
pie2 = Pie()
pie2.add("商品B", attr, v1, center=[45, 50], is_random=False, radius=[20,65], color=["red","green","grey","blue"],rosetype='area', is_legend_show=False, is_label_show=True)
pie2.show_config()
pie2.render(path='./江苏.html')
# Out:
# {'_index_flag': 480574,
#  'backgroundColor': '#fff',
#  'color': ['#c23531',
#            '#2f4554',
#            '#61a0a8',
#            '#d48265',
#            '#749f83',
#            '#ca8622',
#            '#bda29a',
#            '#6e7074',
#            '#546570',
#            '#c4ccd3',
#            '#f05b72',
#            '#ef5b9c',
#            '#f47920',
#            '#905a3d',
#            '#fab27b',
#            '#2a5caa',
#            '#444693',
#            '#726930',
#            '#b2d235',
#            '#6d8346',
#            '#ac6767',
#            '#1d953f',
#            '#6950a1',
#            '#918597',
#            '#f6f5ec'],
#  'legend': [{'data': ['第一产业能耗', '第二产业能耗', '第三产业能耗', '居民生活用能'],
#              'left': 'center',
#              'orient': 'horizontal',
#              'selectedMode': 'multiple',
#              'show': False,
#              'top': 'top'}],
#  'series': [{'center': ['45%', '50%'],
#              'data': [{'name': '第一产业能耗', 'value': 500},
# ...

# %%
dm=pd.read_excel("长三角能源调入调出情况.xlsx",encoding = 'GB2312')
dm1=dm[dm.城市=="浙江"]
dm2=dm[dm.城市=="江苏" ]
dm3=dm[dm.城市=="上海" ]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-1fb52fadb039> in <module>
#       1 dm=pd.read_excel("长三角能源调入调出情况.xlsx",encoding = 'GB2312')
# ----> 2 dm1=dm[dm.城市=="浙江"]
#       3 dm2=dm[dm.城市=="江苏" ]
#       4 dm3=dm[dm.城市=="上海" ]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute '城市'

# %%
plt.figure(figsize=(8,4.2),dpi=150)
plt.subplots_adjust(hspace=0.4, wspace=0.25)
colors=["cornflowerblue","springgreen"]
axes=plt.axes()
plt.subplot(1,2,1)
#plt.ylim((0,15000))
years=["2017年","2018年"]
plt.ylim((31,34))
xxx1=[33.3,32.1]
plt.bar(years, xxx1, color="cornflowerblue",edgecolor='black',width=0.6,label="可再生能源电力消纳比重(%)") 
plt.axhline(32,linestyle='--',color="black",alpha=0.8,label="2019年最低消纳责任权重(%)")
plt.axhline(33,linestyle='-.',color="black",alpha=0.8,label="2020年最低消纳责任权重(%)")
plt.legend()
plt.title("可再生能源电力消纳目标及现状")  
plt.grid(linestyle='-.',alpha=0.5)

plt.subplot(1,2,2)
plt.ylim((2.5,3.5))
xxx2=[2.7,3.3]
plt.bar(years, xxx2, color="springgreen",edgecolor='black',width=0.6,label="非水可再生能源电力消纳比重(%)") 
plt.axhline(3,linestyle='--',color="black",alpha=0.8,label="2019/2020年最低消纳责任权重(%)")
plt.legend(loc=1)

plt.title("非水可再生能源电力消纳目标及现状")  
plt.grid(linestyle='-.',alpha=0.5)


plt.savefig('上海可再生能源配额消纳情况.jpg')

# %%
plt.figure(figsize=(8,4.2),dpi=150)
plt.subplots_adjust(hspace=0.4, wspace=0.25)

axes=plt.axes()
plt.subplot(1,2,1)
years=["2017年","2018年"]
plt.ylim((13,15.5))
xxx1=[14.7,14.7]
plt.bar(years, xxx1, color="cornflowerblue",edgecolor='black',width=0.6,label="可再生能源电力消纳比重(%)") 
plt.axhline(13.5,linestyle='--',color="black",alpha=0.8,label="2019年最低消纳责任权重(%)")
plt.axhline(14,linestyle='-.',color="black",alpha=0.8,label="2020年最低消纳责任权重(%)")
plt.legend()
plt.title("可再生能源电力消纳目标及现状")  
plt.grid(linestyle='-.',alpha=0.5)

plt.subplot(1,2,2)
plt.ylim((4,9))
xxx2=[5.4,7]
plt.bar(years, xxx2, color="springgreen",edgecolor='black',width=0.6,label="非水可再生能源电力消纳比重(%)") 
plt.axhline(6.5,linestyle='--',color="black",alpha=0.8,label="2019年最低消纳责任权重(%)")
plt.axhline(7.5,linestyle='-.',color="black",alpha=0.8,label="2020年最低消纳责任权重(%)")
plt.legend(loc=1)

plt.title("非水可再生能源电力消纳目标及现状")  
plt.grid(linestyle='-.',alpha=0.5)


plt.savefig('江苏可再生能源配额消纳情况.jpg')

# %%
plt.figure(figsize=(8,4.2),dpi=150)
plt.subplots_adjust(hspace=0.4, wspace=0.25)

axes=plt.axes()
plt.subplot(1,2,1)
years=["2017年","2018年"]
plt.ylim((17,20))
xxx1=[19.3,17.8]
plt.bar(years, xxx1, color="cornflowerblue",edgecolor='black',width=0.6,label="可再生能源电力消纳比重(%)") 
plt.axhline(17.5,linestyle='--',color="black",alpha=0.8,label="2019年最低消纳责任权重(%)")
plt.axhline(18.5,linestyle='-.',color="black",alpha=0.8,label="2020年最低消纳责任权重(%)")
plt.legend()
plt.title("可再生能源电力消纳目标及现状")  
plt.grid(linestyle='-.',alpha=0.5)

plt.subplot(1,2,2)
plt.ylim((4,9))
xxx2=[4.2,5.3]
plt.bar(years, xxx2, color="springgreen",edgecolor='black',width=0.6,label="非水可再生能源电力消纳比重(%)") 
plt.axhline(6.5,linestyle='--',color="black",alpha=0.8,label="2019年最低消纳责任权重(%)")
plt.axhline(7.5,linestyle='-.',color="black",alpha=0.8,label="2020年最低消纳责任权重(%)")
plt.legend(loc=1)

plt.title("非水可再生能源电力消纳目标及现状")  
plt.grid(linestyle='-.',alpha=0.5)


plt.savefig('浙江可再生能源配额消纳情况.jpg')

# %%
plt.figure(figsize=(7,5),dpi=150)
plt.subplots_adjust(hspace=0.4, wspace=0.25)
colors=["lightsalmon","cornflowerblue","springgreen"]
plt.subplot(2,2,1)
plt.ylim((0,15000))
plt.bar(dm1.来源, dm1.煤, color=colors,edgecolor='black') 
plt.title("煤炭（万吨）")  
for a,b in zip(dm1.来源,dm1.煤):
    plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=7)
plt.grid(linestyle='-.',alpha=0.5)

plt.subplot(2,2,2)
plt.ylim((-5000,10000))
plt.bar(dm1.来源, dm1.油品, color=colors,edgecolor='black')  
plt.title("油品（万吨）")  
for a,b in zip(dm1.来源,dm1.油品):
    plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=7)
plt.grid(linestyle='-.',alpha=0.5)

plt.subplot(2,2,3)
plt.ylim((0,100))
plt.bar(dm1.来源, dm1.天然气,color=colors,edgecolor='black')  
plt.title("天然气（亿立方米）")  # 指定图表描述信息
for a,b in zip(dm1.来源,dm1.天然气):
    plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=7)
plt.grid(linestyle='-.',alpha=0.5)

plt.subplot(2,2,4)
plt.ylim((-150,900))
plt.bar(dm1.来源, dm1.电力, color=colors,edgecolor='black')  
plt.title("电力（亿千瓦时）") 
plt.grid(linestyle='-.',alpha=0.5)
for a,b in zip(dm1.来源,dm1.电力):
    plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=7)
plt.text(0.5,-400, "数据来源：中国能源统计年鉴", size = 8)    

plt.savefig('浙江能源调入调出情况.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ce6d18695d28> in <module>
#       4 plt.subplot(2,2,1)
#       5 plt.ylim((0,15000))
# ----> 6 plt.bar(dm1.来源, dm1.煤, color=colors,edgecolor='black')
#       7 plt.title("煤炭（万吨）")
#       8 for a,b in zip(dm1.来源,dm1.煤):
#
# NameError: name 'dm1' is not defined

# %%
plt.figure(figsize=(8,4.2),dpi=150)
plt.subplots_adjust(hspace=0.4, wspace=0.25)
colors=["cornflowerblue","springgreen"]
axes=plt.axes()
plt.subplot(1,2,1)
#plt.ylim((0,15000))
years=["2017年","2018年"]
plt.ylim((31,34))
xxx1=[33.3,32.1]
plt.bar(years, xxx1, color="cornflowerblue",edgecolor='black',width=0.6,label="可再生能源电力消纳比重(%)") 
plt.axhline(32,linestyle='--',color="black",alpha=0.8,label="2019年目标值")
plt.axhline(33,linestyle='-.',color="black",alpha=0.8,label="2020年目标值")
plt.legend()
plt.title("可再生能源电力消纳目标及现状")  
plt.grid(linestyle='-.',alpha=0.5)

plt.subplot(1,2,2)
plt.ylim((2.5,3.5))
xxx2=[2.7,3.3]
plt.bar(years, xxx2, color="springgreen",edgecolor='black',width=0.6,label="非水可再生能源电力消纳比重(%)") 
plt.axhline(3,linestyle='--',color="black",alpha=0.8,label="2019/2020年目标值")
plt.legend(loc=1)

plt.title("非水可再生能源电力消纳目标及现状")  
plt.grid(linestyle='-.',alpha=0.5)


plt.savefig('上海可再生能源配额消纳情况.jpg')

# %%
plt.figure(figsize=(7,5),dpi=150)
plt.subplots_adjust(hspace=0.4, wspace=0.25)
colors=["lightsalmon","cornflowerblue","springgreen"]

plt.subplot(2,2,1)
plt.ylim((-2000,30000))
plt.bar(dm2.来源, dm2.煤, color=colors,edgecolor='black') 
plt.title("煤炭（万吨）")  
for a,b in zip(dm2.来源,dm2.煤):
    plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=7)
plt.grid(linestyle='-.',alpha=0.5)

plt.subplot(2,2,2)
plt.ylim((-5000,10000))
plt.bar(dm2.来源, dm2.油品, color=colors,edgecolor='black')  
plt.title("油品（万吨）")  
for a,b in zip(dm2.来源,dm2.油品):
    plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=7)
plt.grid(linestyle='-.',alpha=0.5)

plt.subplot(2,2,3)
plt.ylim((0,200))
plt.bar(dm2.来源, dm2.天然气,color=colors,edgecolor='black')  
plt.title("天然气（亿立方米）")  # 指定图表描述信息
for a,b in zip(dm2.来源,dm2.天然气):
    plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=7)
plt.grid(linestyle='-.',alpha=0.5)

plt.subplot(2,2,4)
plt.ylim((-200,1000))
plt.bar(dm2.来源, dm2.电力, color=colors,edgecolor='black')  
plt.title("电力（亿千瓦时）") 
plt.grid(linestyle='-.',alpha=0.5)
for a,b in zip(dm2.来源,dm2.电力):
    plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=7)
plt.text(0.5,-450, "数据来源：中国能源统计年鉴", size = 8)    

plt.savefig('江苏能源调入调出情况.jpg')

# %%
plt.figure(figsize=(7,5),dpi=150)
plt.subplots_adjust(hspace=0.4, wspace=0.25)
colors=["lightsalmon","cornflowerblue","springgreen"]

plt.subplot(2,2,1)
plt.ylim((-2000,8000))
plt.bar(dm3.来源, dm3.煤, color=colors,edgecolor='black') 
plt.title("煤炭（万吨）")  
for a,b in zip(dm3.来源,dm3.煤):
    plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=7)
plt.grid(linestyle='-.',alpha=0.5)

plt.subplot(2,2,2)
plt.ylim((-10000,15000))
plt.bar(dm3.来源, dm3.油品, color=colors,edgecolor='black')  
plt.title("油品（万吨）")  
for a,b in zip(dm3.来源,dm3.油品):
    plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=7)
plt.grid(linestyle='-.',alpha=0.5)

plt.subplot(2,2,3)
plt.ylim((0,100))
plt.bar(dm3.来源, dm3.天然气,color=colors,edgecolor='black')  
plt.title("天然气（亿立方米）")  # 指定图表描述信息
for a,b in zip(dm3.来源,dm3.天然气):
    plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=7)
plt.grid(linestyle='-.',alpha=0.5)

plt.subplot(2,2,4)
plt.ylim((-100,800))
plt.bar(dm3.来源, dm3.电力, color=colors,edgecolor='black')  
plt.title("电力（亿千瓦时）") 
plt.grid(linestyle='-.',alpha=0.5)
for a,b in zip(dm3.来源,dm3.电力):
    plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=7)
plt.text(0.5,-350, "数据来源：中国能源统计年鉴", size = 8)    

plt.savefig('上海能源调入调出情况.jpg')

# %%
dff = pd.read_csv("潜力分析.csv",encoding = 'GB2312')

# %%
df1=dff[dff.省份=="浙江"]
df2=dff[dff.省份=="江苏" ]
df3=dff[dff.省份=="上海" ]

# %%
plt.figure(figsize=(6,5),dpi=150)
plt.subplots_adjust(hspace=0.6, wspace=0.2)

plt.subplot(2,1,1)
plt.ylim((50,220))
plt.title("能源消费总量（百万吨标煤）")
plt.plot(df1.年份, df1.能源消费总量,linestyle="-.",marker=".", linewidth=1)
plt.xlimit=(6000,11000)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,1,2)
plt.ylim((0,1.25))
plt.title("能源强度（万吨标煤/万元GDP)")
plt.plot(df1.年份, df1.能源强度,linestyle="-.",marker=".",color="g",linewidth=1,c="r")
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.savefig('浙江能源消费情况.jpg')

# %%
plt.figure(figsize=(6,5),dpi=150)
plt.subplots_adjust(hspace=0.6, wspace=0.2)

plt.subplot(2,1,1)
plt.ylim((80,320))
plt.title("能源消费总量（百万吨标煤）")
plt.plot(df2.年份, df2.能源消费总量,linestyle="-.",marker=".", linewidth=1)
plt.xlimit=(6000,11000)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,1,2)
#plt.ylim((1,2.5))
plt.title("能源强度（万吨标煤/万元GDP)")
plt.plot(df2.年份, df2.能源强度,linestyle="-.",marker=".",color="g",linewidth=1,c="r")
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.text(12,0.35, "数据来源：国家统计年鉴", size = 8)

plt.savefig('江苏能源消费情况.jpg')

# %%
plt.figure(figsize=(6,5),dpi=150)
plt.subplots_adjust(hspace=0.6, wspace=0.2)

plt.subplot(2,1,1)
plt.ylim((50,120))
plt.title("能源消费总量（百万吨标煤）")
plt.plot(df3.年份, df3.能源消费总量,linestyle="-.",marker=".", linewidth=1)
plt.xlimit=(6000,11000)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,1,2)
plt.ylim((0,1.25))
plt.title("能源强度（万吨标煤/万元GDP)")
plt.plot(df3.年份, df3.能源强度,linestyle="-.",marker=".",color="g",linewidth=1,c="r")
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.savefig('上海能源消费情况.jpg')

# %%
plt.figure(figsize=(8,5),dpi=200)
plt.subplots_adjust(hspace=0.6, wspace=0.2)

plt.subplot(2,2,1)
plt.ylim((0,40))
plt.title("实际GDP（亿元）")
plt.plot(df1.年份, df1.实际GDP,linestyle="-.",marker=".", linewidth=1)
plt.xlimit=(6000,11000)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,2)
plt.ylim((0,60))
plt.title("人均实际GDP（万元）")
plt.plot(df1.年份, df1.人均实际GDP,linestyle="-.",marker=".",color="g",linewidth=1,c="r")
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,3)
plt.ylim((4500,6000))
plt.title("总人口（万人）")
plt.plot(df1.年份, df1.总人口,linestyle="-.",marker=".",color="blueviolet",linewidth=1)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,4)
plt.ylim((0.55,0.7))
plt.title("城镇化率")
plt.plot(df1.年份, df1.城镇化率,linestyle="-.",marker=".",color="grey",linewidth=1)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.text(10,0.488, "数据来源：国家统计年鉴", size = 8)

plt.savefig('浙江经济社会发展情况.jpg')

# %%
plt.figure(figsize=(8,5),dpi=200)
plt.subplots_adjust(hspace=0.6, wspace=0.2)

plt.subplot(2,2,1)
plt.ylim((0,70))
plt.title("实际GDP（亿元）")
plt.plot(df2.年份, df2.实际GDP,linestyle="-.",marker=".", linewidth=1)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,2)
plt.ylim((0,70))
plt.title("人均实际GDP（万元）")
plt.plot(df2.年份, df2.人均实际GDP,linestyle="-.",marker=".",color="g",linewidth=1,c="r")
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,3)
plt.ylim((7200,8200))
plt.title("总人口（万人）")
plt.plot(df2.年份, df2.总人口,linestyle="-.",marker=".",color="blueviolet",linewidth=1)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,4)
plt.ylim((0.5,0.7))
plt.title("城镇化率")
plt.plot(df2.年份, df2.城镇化率,linestyle="-.",marker=".",color="grey",linewidth=1)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.text(10,0.42, "数据来源：国家统计年鉴", size = 8)

plt.savefig('江苏经济社会发展情况.jpg')

# %%
plt.figure(figsize=(8,5),dpi=200)
plt.subplots_adjust(hspace=0.6, wspace=0.2)

plt.subplot(2,2,1)
plt.ylim((0,20))
plt.title("实际GDP（亿元）")
plt.plot(df3.年份, df3.实际GDP,linestyle="-.",marker=".", linewidth=1)

plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,2)
plt.ylim((0,65))
plt.title("人均实际GDP（万元）")
plt.plot(df3.年份, df3.人均实际GDP,linestyle="-.",marker=".",color="g",linewidth=1,c="r")
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,3)
plt.ylim((1500,2500))
plt.title("总人口（万人）")
plt.plot(df3.年份, df3.总人口,linestyle="-.",marker=".",color="blueviolet",linewidth=1)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,4)
plt.ylim((0.87,0.9))
plt.title("城镇化率")
plt.plot(df3.年份, df3.城镇化率,linestyle="-.",marker=".",color="grey",linewidth=1)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.text(10,0.858, "数据来源：国家统计年鉴", size = 8)

plt.savefig('上海经济社会发展情况.jpg')

# %%
dm=pd.read_csv("京津冀.csv",encoding = 'GB2312')
dm1=dm[dm.省份=="北京"]
dm2=dm[dm.省份=="天津" ]
dm3=dm[dm.省份=="河北" ]
dm4=dm[dm.省份=="广东" ]

# %%
plt.figure(figsize=(8,5),dpi=200)
plt.subplots_adjust(hspace=0.6, wspace=0.2)

plt.subplot(2,2,1)
plt.ylim((0,20))
plt.title("实际GDP（亿元）")
plt.plot(dm1.年份, dm1.实际GDP,linestyle="-.",marker=".", linewidth=1)

plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,2)
plt.ylim((0,80))
plt.title("人均实际GDP（万元）")
plt.plot(dm1.年份, dm1.人均实际GDP,linestyle="-.",marker=".",color="g",linewidth=1,c="r")
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,3)
plt.ylim((1200,2400))
plt.title("总人口（万人）")
plt.plot(dm1.年份, dm1.总人口,linestyle="-.",marker=".",color="blueviolet",linewidth=1)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,4)
plt.ylim((0.8,0.9))
plt.title("城镇化率")
plt.plot(dm1.年份, dm1.城镇化率,linestyle="-.",marker=".",color="grey",linewidth=1)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.text(10,0.75, "数据来源：国家统计年鉴", size = 8)

plt.savefig('北京经济社会发展情况.jpg')

# %%
plt.figure(figsize=(8,5),dpi=200)
plt.subplots_adjust(hspace=0.6, wspace=0.2)

plt.subplot(2,2,1)
plt.ylim((0,18))
plt.title("实际GDP（亿元）")
plt.plot(dm2.年份, dm2.实际GDP,linestyle="-.",marker=".", linewidth=1)

plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,2)
plt.ylim((0,120))
plt.title("人均实际GDP（万元）")
plt.plot(dm2.年份, dm2.人均实际GDP,linestyle="-.",marker=".",color="g",linewidth=1,c="r")
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,3)
plt.ylim((1000,1600))
plt.title("总人口（万人）")
plt.plot(dm2.年份, dm2.总人口,linestyle="-.",marker=".",color="blueviolet",linewidth=1)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,4)
plt.ylim((0.74,0.84))
plt.title("城镇化率")
plt.plot(dm2.年份, dm2.城镇化率,linestyle="-.",marker=".",color="grey",linewidth=1)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

#plt.text(10,0.75, "数据来源：国家统计年鉴", size = 8)

plt.savefig('天津经济社会发展情况.jpg')

# %%
plt.figure(figsize=(8,5),dpi=200)
plt.subplots_adjust(hspace=0.6, wspace=0.2)

plt.subplot(2,2,1)
plt.ylim((0,61))
plt.title("实际GDP（亿元）")
plt.plot(dm4.年份, dm4.实际GDP,linestyle="-.",marker=".", linewidth=1)

plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,2)
plt.ylim((0,60))
plt.title("人均实际GDP（万元）")
plt.plot(dm4.年份, dm4.人均实际GDP,linestyle="-.",marker=".",color="g",linewidth=1,c="r")
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,3)
plt.ylim((8000,12000))
plt.title("总人口（万人）")
plt.plot(dm4.年份, dm4.总人口,linestyle="-.",marker=".",color="blueviolet",linewidth=1)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,4)
plt.ylim((0.6,0.72))
plt.title("城镇化率")
plt.plot(dm4.年份, dm4.城镇化率,linestyle="-.",marker=".",color="grey",linewidth=1)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

#plt.text(10,0.75, "数据来源：国家统计年鉴", size = 8)

plt.savefig('广州经济社会发展情况.jpg')

# %%
plt.figure(figsize=(8,5),dpi=200)
plt.subplots_adjust(hspace=0.6, wspace=0.2)

plt.subplot(2,2,1)
plt.ylim((0,20))
plt.title("实际GDP（亿元）")
plt.plot(dm3.年份, dm3.实际GDP,linestyle="-.",marker=".", linewidth=1)

plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,2)
plt.ylim((0,27))
plt.title("人均实际GDP（万元）")
plt.plot(dm3.年份, dm3.人均实际GDP,linestyle="-.",marker=".",color="g",linewidth=1,c="r")
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,3)
plt.ylim((6600,7600))
plt.title("总人口（万人）")
plt.plot(dm3.年份, dm3.总人口,linestyle="-.",marker=".",color="blueviolet",linewidth=1)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,2,4)
plt.ylim((0.35,0.55))
plt.title("城镇化率")
plt.plot(dm3.年份, dm3.城镇化率,linestyle="-.",marker=".",color="grey",linewidth=1)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

#plt.text(10,0.75, "数据来源：国家统计年鉴", size = 8)

plt.savefig('河北经济社会发展情况.jpg')

# %%
plt.figure(figsize=(6,5),dpi=150)
plt.subplots_adjust(hspace=0.6, wspace=0.2)

plt.subplot(2,1,1)
plt.ylim((40,75))
plt.title("能源消费总量（百万吨标煤）")
plt.plot(dm1.年份, dm1.能源消费总量,linestyle="-.",marker=".", linewidth=1)
plt.xlimit=(6000,11000)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,1,2)
plt.ylim((0,1.5))
plt.title("能源强度（万吨标煤/万元GDP)")
plt.plot(dm1.年份, dm1.能源强度,linestyle="-.",marker=".",color="g",linewidth=1,c="r")
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.savefig('北京能源消费情况.jpg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))

# %%
plt.figure(figsize=(6,5),dpi=150)
plt.subplots_adjust(hspace=0.6, wspace=0.2)

plt.subplot(2,1,1)
plt.ylim((25,85))
plt.title("能源消费总量（百万吨标煤）")
plt.plot(dm2.年份, dm2.能源消费总量,linestyle="-.",marker=".", linewidth=1)
plt.xlimit=(6000,11000)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,1,2)
plt.ylim((0,1.6))
plt.title("能源强度（万吨标煤/万元GDP)")
plt.plot(dm2.年份, dm2.能源强度,linestyle="-.",marker=".",color="g",linewidth=1,c="r")
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.savefig('天津能源消费情况.jpg')

# %%
plt.figure(figsize=(6,5),dpi=150)
plt.subplots_adjust(hspace=0.6, wspace=0.2)

plt.subplot(2,1,1)
plt.ylim((110,310))
plt.title("能源消费总量（百万吨标煤）")
plt.plot(dm3.年份, dm3.能源消费总量,linestyle="-.",marker=".", linewidth=1)
plt.xlimit=(6000,11000)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,1,2)
plt.ylim((0,2.5))
plt.title("能源强度（万吨标煤/万元GDP)")
plt.plot(dm3.年份, dm3.能源强度,linestyle="-.",marker=".",color="g",linewidth=1,c="r")
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.savefig('河北能源消费情况.jpg')

# %%
plt.figure(figsize=(6,5),dpi=150)
plt.subplots_adjust(hspace=0.6, wspace=0.2)

plt.subplot(2,1,1)
plt.ylim((70,300))
plt.title("能源消费总量（百万吨标煤）")
plt.plot(dm4.年份, dm4.能源消费总量,linestyle="-.",marker=".", linewidth=1)
plt.xlimit=(6000,11000)
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.subplot(2,1,2)
plt.ylim((0,0.8))
plt.title("能源强度（万吨标煤/万元GDP)")
plt.plot(dm4.年份, dm4.能源强度,linestyle="-.",marker=".",color="g",linewidth=1,c="r")
plt.yticks(size=10)
plt.xticks(rotation=90,size=9)
plt.grid()

plt.savefig('广东能源消费情况.jpg')
